# %%
bertsum_key = ['cells', 'cell', 'prokaryotic', 'prokaryotic cells', 'nucleus', 'smallest living', 'smallest living units', 'living', 'living units', 'units', 'organism', 'membrane-enclosed organelles', 'second category', 'broad categories', 'cell parts', 'cell membrane', 'different materials', 'more mitochondria', 'more energy', 'sac-like structures', 'things', 'type', 'environment', 'common']
bertsum_map = {'cells': ["All cells have a cell membrane, which separates the inside of the cell from the cell's environment.", 'All cells have three things in common, no matter what type of cell All cells are.', 'Cells are the smallest living units of an organism.', 'Cells that need more energy have more mitochondria.', 'There are two broad categories of cells.'], 'cell': ["All cells have a cell membrane, which separates the inside of the cell from the cell's environment.", 'All cells have three things in common, no matter what type of cell All cells are.', "Meanwhile, the cell maintains the cell's shape through a cytoskeleton."], 'prokaryotic cells': ["prokaryotic cells don't have a nucleus or membrane-enclosed organelles.", 'The second category is prokaryotic cells.'], 'nucleus': ["prokaryotic cells don't have a nucleus or membrane-enclosed organelles.", "Let's start with the nucleus."], 'smallest living units': ['Cells are the smallest living units of an organism.'], 'organism': ['Cells are the smallest living units of an organism.'], 'membrane-enclosed organelles': ["prokaryotic cells don't have a nucleus or membrane-enclosed organelles."], 'second category': ['The second category is prokaryotic cells.'], 'broad categories': ['There are two broad categories of cells.'], 'cell parts': ['Vesomes are filled with enzymes that break down damaged or worn-out cell parts.'], 'cell membrane': ["All cells have a cell membrane, which separates the inside of the cell from the cell's environment."], 'different materials': ['Vacuoles are sac-like structures that store different materials.'], 'more mitochondria': ['Cells that need more energy have more mitochondria.'], 'more energy': ['Cells that need more energy have more mitochondria.'], 'sac-like structures': ['Vacuoles are sac-like structures that store different materials.'], 'things': ['All cells have three things in common, no matter what type of cell All cells are.'], 'type': ['All cells have three things in common, no matter what type of cell All cells are.'], 'environment': ["All cells have a cell membrane, which separates the inside of the cell from the cell's environment."], 'common': ['All cells have three things in common, no matter what type of cell All cells are.']}

# %%
ss_key = ['cells', 'category', 'flagella', 'eukaryotic', 'eukaryotic cells', 'second category', 'prokaryotic', 'prokaryotic cells', 'organelles', 'organelles means', 'little organ', 'first category', 'unique feature', 'bacteria']
ss_map = {'cells': ['Another unique feature in some cells is flagella.'], 'flagella': ['Another unique feature in some cells is flagella.', 'Some bacteria have flagella.'], 'eukaryotic cells': ['The first category is eukaryotic cells.'], 'second category': ['The second category is prokaryotic cells.'], 'prokaryotic cells': ['The second category is prokaryotic cells.'], 'organelles means': ['Organelles means little organ.'], 'little organ': ['Organelles means little organ.'], 'first category': ['The first category is eukaryotic cells.'], 'unique feature': ['Another unique feature in some cells is flagella.'], 'bacteria': ['Some bacteria have flagella.']}

# %%
intersection_key = intersection(bertsum_key,ss_key)

# %%
intersection_key
# Out:
# ['cells', 'prokaryotic', 'prokaryotic cells', 'second category']

# %%
#//Video 1
bertsum_key1 = ['forces', 'electric', 'waves', 'electromagnetism', 'electromagnetic', 'electromagnetic force', 'force', 'fundamental', 'fundamental forces', 'nature', 'electric forces', 'high-frequency wavelengths', 'magnetic field', 'field', 'low-frequency waves', 'electric current', 'gamma radiation', 'human body', 'ultraviolet', 'atoms']
bertsum_map1 = {'waves': ['Unlike low-frequency waves, these waves can pass through the human body, making them useful for medical applications.'], 'electromagnetism': ['Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'electromagnetic force': ['Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'fundamental forces': ['Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'nature': ['Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'electric forces': ['These electric forces bring and hold atoms together.'], 'high-frequency wavelengths': ['On the other are short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation.'], 'magnetic field': ['If those electrically charged particles start to move, the field will become a flowing electric current and form a magnetic field around it.'], 'field': ['If those electrically charged particles start to move, the field will become a flowing electric current and form a magnetic field around it.'], 'low-frequency waves': ['Unlike low-frequency waves, these waves can pass through the human body, making them useful for medical applications.'], 'electric current': ['If those electrically charged particles start to move, the field will become a flowing electric current and form a magnetic field around it.'], 'gamma radiation': ['On the other are short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation.'], 'human body': ['Unlike low-frequency waves, these waves can pass through the human body, making them useful for medical applications.'], 'ultraviolet': ['On the other are short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation.'], 'atoms': ['These electric forces bring and hold atoms together.']}
ss_key1 = ['waves', 'electromagnetic', 'electromagnetism', 'radiation', 'electric', 'positive', 'negative', 'electromagnetic force', 'force', 'charge', 'fundamental forces', 'world', 'electromagnetic energy', 'electric charge', 'radio signals', 'negative charge', 'high-frequency wavelengths', 'invisible electromagnetic waves', 'low-frequency radio waves', 'low-frequency waves', 'micro waves', 'gamma radiation', 'electromagnetic spectrum']
ss_map1 = {'waves': ['On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.', "The intensity of waves of electromagnetic energy or radiation is determined by waves of electromagnetic energy or radiation's frequency."], 'electromagnetism': ['a protective layer around the planet shields us from the most harmful radiation in space, leaving us to enjoy a world held together by Electromagnetism, or the electromagnetic force,.', "While electromagnetism has daily applications, electromagnetism's also the engine that drives the world as we know it.", 'Electromagnetism is a branch of physics that studies the interactions between electric and magnetic fields.', 'Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'radiation': ['a protective layer around the planet shields us from the most harmful radiation in space, leaving us to enjoy a world held together by Electromagnetism, or the electromagnetic force,.', "The intensity of waves of electromagnetic energy or radiation is determined by waves of electromagnetic energy or radiation's frequency."], 'electric': ['And when atoms gain a positive or negative charge through the transfer of electrons, a measurable electric field will form.', 'Electromagnetism is a branch of physics that studies the interactions between electric and magnetic fields.'], 'positive': ["Called a geodynamo, this process causes the world as we know it's poles to attain positive and negative charges, turning the world as we know it into a giant electromagnet.", 'And when atoms gain a positive or negative charge through the transfer of electrons, a measurable electric field will form.', 'All matter has an electric charge, which can be positive, negative, or zero.'], 'negative': ["Called a geodynamo, this process causes the world as we know it's poles to attain positive and negative charges, turning the world as we know it into a giant electromagnet.", 'All matter has an electric charge, which can be positive, negative, or zero.'], 'electromagnetic force': ['a protective layer around the planet shields us from the most harmful radiation in space, leaving us to enjoy a world held together by Electromagnetism, or the electromagnetic force,.', 'Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'fundamental forces': ['Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.'], 'world': ['a protective layer around the planet shields us from the most harmful radiation in space, leaving us to enjoy a world held together by Electromagnetism, or the electromagnetic force,.', "Called a geodynamo, this process causes the world as we know it's poles to attain positive and negative charges, turning the world as we know it into a giant electromagnet.", "While electromagnetism has daily applications, electromagnetism's also the engine that drives the world as we know it."], 'electromagnetic energy': ["The intensity of waves of electromagnetic energy or radiation is determined by waves of electromagnetic energy or radiation's frequency."], 'electric charge': ['All matter has an electric charge, which can be positive, negative, or zero.'], 'radio signals': ['On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.'], 'negative charge': ['And when atoms gain a positive or negative charge through the transfer of electrons, a measurable electric field will form.'], 'high-frequency wavelengths': ['Unlike low-frequency waves, short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation can pass through the human body, making short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation useful for medical applications.'], 'invisible electromagnetic waves': ['On either side are invisible electromagnetic waves.'], 'low-frequency radio waves': ['On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.'], 'low-frequency waves': ['Unlike low-frequency waves, short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation can pass through the human body, making short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation useful for medical applications.'], 'micro waves': ['On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.'], 'gamma radiation': ['Unlike low-frequency waves, short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation can pass through the human body, making short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation useful for medical applications.'], 'electromagnetic spectrum': ['Near the middle of the electromagnetic spectrum is visible light, such as light emitted by stars, fireflies, and computer screens.']}

# %%
def intersection(lbert, lss):
    lin = [value for value in lbert if value in lss]
    return lin

# %%
# //Video 2
bertsum_key2 = ['plants', 'photosynthesis', 'means', 'pores', 'glucose', 'carbon', 'carbon dioxide', 'water', 'kids know', 'food', 'kids', 'growth', 'process', 'essential factors', 'chemical energy', 'complex terms', 'own food', 'venous fly traps', 'photo', 'light']
bertsum_map2 = {'plants': ["some plants which don't need the process of photosynthesis to grow include mushroom, venous fly traps etc.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms.", 'chemical energy is used by plants for growth and nourishment.', "Glucose is used by the plants for the plants's growth.", "Do kids know how plants make plants's own food?"], 'photosynthesis': ["some plants which don't need the process of photosynthesis to grow include mushroom, venous fly traps etc.", 'So the essential factors for photosynthesis to take place include sunlight, water and carbon dioxide.', "Photosynthesis is the process used by plants to make plants's own food or in more complex terms."], 'means': ['Photo means light and synthesis means putting together in Greek.'], 'pores': ['pores, very similar to the pores on the skin of our bodies are responsible for the exchange of gases.'], 'glucose': ['Carbohydrates, which are a form of glucose, are synthesized from carbon dioxide and water.', "Glucose is used by the plants for the plants's growth."], 'carbon dioxide': ['So the essential factors for photosynthesis to take place include sunlight, water and carbon dioxide.', 'Carbohydrates, which are a form of glucose, are synthesized from carbon dioxide and water.'], 'water': ['So the essential factors for photosynthesis to take place include sunlight, water and carbon dioxide.', 'Carbohydrates, which are a form of glucose, are synthesized from carbon dioxide and water.'], 'kids know': ["Do kids know how plants make plants's own food?"], 'growth': ['chemical energy is used by plants for growth and nourishment.', "Glucose is used by the plants for the plants's growth."], 'process': ["some plants which don't need the process of photosynthesis to grow include mushroom, venous fly traps etc.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms."], 'essential factors': ['So the essential factors for photosynthesis to take place include sunlight, water and carbon dioxide.'], 'chemical energy': ['chemical energy is used by plants for growth and nourishment.'], 'complex terms': ["Photosynthesis is the process used by plants to make plants's own food or in more complex terms."], 'own food': ["Photosynthesis is the process used by plants to make plants's own food or in more complex terms.", "Do kids know how plants make plants's own food?"], 'venous fly traps': ["some plants which don't need the process of photosynthesis to grow include mushroom, venous fly traps etc."], 'photo': ['Photo means light and synthesis means putting together in Greek.'], 'light': ['Photo means light and synthesis means putting together in Greek.']}
ss_key2 = ['plants', 'photosynthesis', 'called', 'leaves', 'pores', 'plant', 'energy', 'green color', 'water', 'process', 'important cells', 'word photosynthesis', 'respiration process', 'own food', 'water layers', 'green color component', 'mesofil cells', 'chemical energy', 'similar', 'bodies', 'chloroplasts']
ss_map2 = {'plants': ['Plants have tubes called xylum, located in the stems through which the water from the ground is sucked into the leaves.', 'a green color component called chloroplasts is responsible for the green color of plants and leaves.', "Well, this video elaborates the process of photosynthesis by which plants make plants's own food.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms.", 'Photosynthesis is the conversion of light energy into chemical energy by plants.', 'chemical energy is used by plants for growth and nourishment.', "Glucose is used by the plants for the plants's growth.", "Do kids know how plants make plants's own food?"], 'photosynthesis': ["The oxygen that is released is used by human beings to breathe during human beings's respiration process ever wondered why the process of photosynthesis is called photosynthesis?", 'Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'The carbon dioxide present in the air, which is responsible for Photosynthesis, enters the plant through pores, very similar to the pores on the skin of our bodies.', 'The following reaction takes place in the leaves of the plant during the process of photosynthesis.', "Well, this video elaborates the process of photosynthesis by which plants make plants's own food.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms.", 'Photosynthesis is the conversion of light energy into chemical energy by plants.'], 'called': ["The oxygen that is released is used by human beings to breathe during human beings's respiration process ever wondered why the process of photosynthesis is called photosynthesis?", 'Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'Plants have tubes called xylum, located in the stems through which the water from the ground is sucked into the leaves.', 'a green color component called chloroplasts is responsible for the green color of plants and leaves.', 'important cells called mesofil cells contain a green color component called chloroplasts.', 'pores, very similar to the pores on the skin of our bodies are called stomata.', 'Leaves have important cells called mesofil cells.'], 'leaves': ['This system is spread throughout the different parts of the plant, including the stem, branches, and all the way up to the leaves.', 'Plants have tubes called xylum, located in the stems through which the water from the ground is sucked into the leaves.', 'a green color component called chloroplasts is responsible for the green color of plants and leaves.', 'The following reaction takes place in the leaves of the plant during the process of photosynthesis.', 'Leaves on the plant have pores, very similar to the pores on the skin of our bodies.', 'Leaves have important cells called mesofil cells.'], 'pores': ['The carbon dioxide present in the air, which is responsible for Photosynthesis, enters the plant through pores, very similar to the pores on the skin of our bodies.', 'Leaves on the plant have pores, very similar to the pores on the skin of our bodies.', 'pores, very similar to the pores on the skin of our bodies are called stomata.'], 'plant': ['The carbon dioxide present in the air, which is responsible for Photosynthesis, enters the plant through pores, very similar to the pores on the skin of our bodies.', 'Xylums in the plant are like blood vessels in the human body that act as an important means of transportation of water and nutrients.', 'This system is spread throughout the different parts of the plant, including the stem, branches, and all the way up to the leaves.', 'This is because energy from the sun is absorbed by the water layers and only some amount of energy actually reaches the plant.', 'The following reaction takes place in the leaves of the plant during the process of photosynthesis.', 'Leaves on the plant have pores, very similar to the pores on the skin of our bodies.', 'This system transports vital nutrients to the plant.'], 'energy': ['This is because energy from the sun is absorbed by the water layers and only some amount of energy actually reaches the plant.', 'Photosynthesis is the conversion of light energy into chemical energy by plants.'], 'green color': ['a green color component called chloroplasts is responsible for the green color of plants and leaves.'], 'water': ['Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'Xylums in the plant are like blood vessels in the human body that act as an important means of transportation of water and nutrients.', 'Plants have tubes called xylum, located in the stems through which the water from the ground is sucked into the leaves.'], 'process': ["The oxygen that is released is used by human beings to breathe during human beings's respiration process ever wondered why the process of photosynthesis is called photosynthesis?", 'Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'The following reaction takes place in the leaves of the plant during the process of photosynthesis.', "Well, this video elaborates the process of photosynthesis by which plants make plants's own food.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms."], 'important cells': ['important cells called mesofil cells contain a green color component called chloroplasts.', 'Leaves have important cells called mesofil cells.'], 'word photosynthesis': ['Well the word photosynthesis is a combination of two Greek words photo and synthesis.'], 'respiration process': ["The oxygen that is released is used by human beings to breathe during human beings's respiration process ever wondered why the process of photosynthesis is called photosynthesis?"], 'own food': ["Well, this video elaborates the process of photosynthesis by which plants make plants's own food.", "Photosynthesis is the process used by plants to make plants's own food or in more complex terms.", "Do kids know how plants make plants's own food?"], 'water layers': ['This is because energy from the sun is absorbed by the water layers and only some amount of energy actually reaches the plant.'], 'green color component': ['Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'a green color component called chloroplasts is responsible for the green color of plants and leaves.', 'important cells called mesofil cells contain a green color component called chloroplasts.'], 'mesofil cells': ['important cells called mesofil cells contain a green color component called chloroplasts.', 'Leaves have important cells called mesofil cells.'], 'chemical energy': ['Photosynthesis is the conversion of light energy into chemical energy by plants.', 'chemical energy is used by plants for growth and nourishment.'], 'similar': ['The carbon dioxide present in the air, which is responsible for Photosynthesis, enters the plant through pores, very similar to the pores on the skin of our bodies.', 'Leaves on the plant have pores, very similar to the pores on the skin of our bodies.', 'pores, very similar to the pores on the skin of our bodies are called stomata.', 'This system works similar to humans sucking liquids through a straw.'], 'bodies': ['The carbon dioxide present in the air, which is responsible for Photosynthesis, enters the plant through pores, very similar to the pores on the skin of our bodies.', 'Leaves on the plant have pores, very similar to the pores on the skin of our bodies.', 'pores, very similar to the pores on the skin of our bodies are called stomata.'], 'chloroplasts': ['Once the carbon dioxide and the water reach a green color component called chloroplasts in the presence of sunlight, the process of photosynthesis starts to take place.', 'a green color component called chloroplasts is responsible for the green color of plants and leaves.', 'important cells called mesofil cells contain a green color component called chloroplasts.']}

# %%
# //Video 3
bertsum_key3 = ['vitamins', 'body', 'blood', 'vitamin', 'helps', 'cells', 'random out-of-order', 'random out-of-order alphabet', 'out-of-order', 'out-of-order alphabet', 'vitamin a', 'heart disorders', 'nerve damage', 'shape bones', 'k. no', 'white blood cells', 'stores vitamins', 'fat-soluble vitamins', 'vitamin variety', 'problems', 'range', 'lipid-soluble', 'a', 'c', 'b', 'e', 'd']
bertsum_map3 = {'vitamins': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.', 'Once inside the system, these foods are digested, and the vitamins within them are taken up directly by the bloodstream.'], 'body': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.', "Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'blood': ["Because fat-soluble vitamins can't make use of the blood's watery nature, they need something else to move them around."], 'helps': ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'cells': ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'random out-of-order alphabet': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'vitamin a': ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'heart disorders': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.'], 'nerve damage': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.'], 'shape bones': ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'k. no': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'white blood cells': ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], 'stores vitamins': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.'], 'fat-soluble vitamins': ["Because fat-soluble vitamins can't make use of the blood's watery nature, they need something else to move them around."], 'vitamin variety': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.'], 'problems': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.'], 'range': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.'], 'lipid-soluble': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.'], 'a': ['Without this vitamin variety, humans face deficiencies that cause a range of problems like fatigue, nerve damage, heart disorders, or diseases like rickets and scurvy.', "A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'c': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'b': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'e': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."], 'd': ["A, C, E, D, B, K. No, this isn't some random out-of-order alphabet."]}
ss_key3 = ['vitamins', 'body', 'fat-soluble', 'fat-soluble vitamins', 'vitamin', 'water-soluble', 'water-solubles', 'types', 'blood', 'lipid-soluble', 'maintenance workers', 'heal wounds', 'b-complex vitamins', 'use', 'vitamin c', 'water-soluble vitamins c', 'lipid-soluble vitamins', 'stores vitamins', 'form vitamins', 'different types', 'fat']
ss_map3 = {'vitamins': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.', "Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds.", 'Vitamins are organic compounds we need to ingest in small amounts to keep functioning.', 'So how does the body get vitamins from out there into here?'], 'body': ["The body treats these parts like a pantry, storing fat-soluble vitamins there and rationing fat-soluble vitamins out when needed, meaning we shouldn't overload on this type of vitamin because The body is generally well stocked.", 'Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.', "Because blood plasma is water-based, water-soluble vitamins C and B have water-soluble vitamins C and B's transport cut out for water-soluble vitamins C and B, and can move around freely within the body.", "So this difference between water or fat-soluble vitamins determines how fat-soluble vitamins get into the blood, but also how fat-soluble vitamins're stored or rejected from the body.", "Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds.", "The water-solubles are dissolved in the watery parts of fruits, vegetables, and grains, meaning The water-solubles's passage through the body is relatively straightforward.", 'Vitamin D gathers calcium and phosphorus so we can make bones, and vitamin E works as an antioxidant, getting rid of elements in the body that can damage cells.', 'On the other hand, too much of any vitamin can cause toxicity in the body, so there goes the myth that loading yourself with supplements is a great idea.', "And just like letters build words, letters're the building blocks that keep the body running.", 'So how does the body get vitamins from out there into here?'], 'fat-soluble vitamins': ["The body treats these parts like a pantry, storing fat-soluble vitamins there and rationing fat-soluble vitamins out when needed, meaning we shouldn't overload on this type of vitamin because The body is generally well stocked.", "So this difference between water or fat-soluble vitamins determines how fat-soluble vitamins get into the blood, but also how fat-soluble vitamins're stored or rejected from the body.", "Because fat-soluble vitamins can't make use of the blood's watery nature, fat-soluble vitamins need something else to move fat-soluble vitamins around."], 'vitamin': ["The body treats these parts like a pantry, storing fat-soluble vitamins there and rationing fat-soluble vitamins out when needed, meaning we shouldn't overload on this type of vitamin because The body is generally well stocked.", 'Vitamin D gathers calcium and phosphorus so we can make bones, and vitamin E works as an antioxidant, getting rid of elements in the body that can damage cells.', 'On the other hand, too much of any vitamin can cause toxicity in the body, so there goes the myth that loading yourself with supplements is a great idea.'], 'water-soluble': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.'], 'water-solubles': ["The water-solubles are dissolved in the watery parts of fruits, vegetables, and grains, meaning The water-solubles's passage through the body is relatively straightforward.", 'The water-solubles are vitamin C and B-complex vitamins that are made up of eight different types that each do something unique.'], 'types': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.'], 'blood': ["Because blood plasma is water-based, water-soluble vitamins C and B have water-soluble vitamins C and B's transport cut out for water-soluble vitamins C and B, and can move around freely within the body.", "So this difference between water or fat-soluble vitamins determines how fat-soluble vitamins get into the blood, but also how fat-soluble vitamins're stored or rejected from the body.", "Because fat-soluble vitamins can't make use of the blood's watery nature, fat-soluble vitamins need something else to move fat-soluble vitamins around."], 'lipid-soluble': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.'], 'maintenance workers': ["Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds."], 'heal wounds': ["Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds."], 'b-complex vitamins': ['The water-solubles are vitamin C and B-complex vitamins that are made up of eight different types that each do something unique.'], 'use': ["Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds.", "Because fat-soluble vitamins can't make use of the blood's watery nature, fat-soluble vitamins need something else to move fat-soluble vitamins around."], 'vitamin c': ['The water-solubles are vitamin C and B-complex vitamins that are made up of eight different types that each do something unique.'], 'water-soluble vitamins c': ["Because blood plasma is water-based, water-soluble vitamins C and B have water-soluble vitamins C and B's transport cut out for water-soluble vitamins C and B, and can move around freely within the body."], 'lipid-soluble vitamins': ['lipid-soluble vitamins, dissolved in fat and found in foods like dairy, butter, and oils make it through the stomach and the intestine, where an acidic substance called bile flows in from the liver, breaking up the fat and preparing the fat for absorption through the intestinal wall.'], 'stores vitamins': ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.'], 'form vitamins': ["That's dependent on the form vitamins take."], 'different types': ['The water-solubles are vitamin C and B-complex vitamins that are made up of eight different types that each do something unique.'], 'fat': ['lipid-soluble vitamins, dissolved in fat and found in foods like dairy, butter, and oils make it through the stomach and the intestine, where an acidic substance called bile flows in from the liver, breaking up the fat and preparing the fat for absorption through the intestinal wall.']}

# %%
# //video 4
bertsum_key4 = ['charged', 'energy', 'nucleus', 'structure', 'points', 'revolve', 'sun', 'electron', 'atom', 'rutherford', 'atomic model', 'niels bohr', 'circular motion gains', 'typical atom', 'slight modifications', 'k l m n', 'circular motion gains acceleration', 'next legendary scientist', 'neutral neutrons', 'atoms']
bertsum_map4 = {'charged': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'We know that any charged object which revolves in a circular motion gains acceleration gradually.'], 'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'], 'nucleus': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'], 'structure': ['With all these theories and points known, do we now know the structure of a typical atom completely?', "Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."], 'points': ['With all these theories and points known, do we now know the structure of a typical atom completely?', 'Now these points definitely tell us why an atom is so stable.'], 'revolve': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'Now here, the sun is stationary at the centre while the planets revolve around the sun.'], 'sun': ['Now here, the sun is stationary at the centre while the planets revolve around the sun.'], 'electron': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'], 'atom': ['Now these points definitely tell us why an atom is so stable.', 'Is that how an atom is structured?'], 'rutherford': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."], 'atomic model': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."], 'niels bohr': ['slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'typical atom': ['With all these theories and points known, do we now know the structure of a typical atom completely?'], 'slight modifications': ['slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'k l m n': ['Yes, K L M N and so on.'], 'circular motion gains acceleration': ['We know that any charged object which revolves in a circular motion gains acceleration gradually.'], 'next legendary scientist': ['slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'neutral neutrons': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'], 'atoms': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."]}
ss_key4 = ['electrons', 'fixed', 'orbitals', 'energy', 'nucleus', 'defined', 'fixed defined', 'fixed defined orbitals', 'defined orbitals', 'called', 'orbits', 'niels bohr', 'subatomic particle', 'different path', 'solar system', 'slight modifications', 'next legendary scientist', 'electrons revolve', 'name energy levels', 'certain special orbits', 'electron', 'atomic model', 'planets', 'rutherford', 'few additional explanations']
ss_map4 = {'electrons': ['the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.', 'The nucleus acts like the sun and the electrons are like planets which revolve in fixed defined orbitals.', 'Firstly, only certain special orbits called discrete orbits of electrons are allowed inside the atom.', 'The nucleus contains positive protons and the electrons revolving around in fixed orbitals.', 'Is there a way to find out the maximum number of electrons that one orbital can contain?', 'Or is it that the electrons are randomly scattered in fixed orbitals around the nucleus?', 'But how exactly are the electrons distributed in fixed orbitals around the nucleus?'], 'fixed': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'The nucleus contains positive protons and the electrons revolving around in fixed orbitals.', 'Or is it that the electrons are randomly scattered in fixed orbitals around the nucleus?', 'But how exactly are the electrons distributed in fixed orbitals around the nucleus?', 'But have you noticed that the planets always revolve in fixed paths?'], 'orbitals': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'The nucleus contains positive protons and the electrons revolving around in fixed orbitals.', 'Or is it that the electrons are randomly scattered in fixed orbitals around the nucleus?', 'But how exactly are the electrons distributed in fixed orbitals around the nucleus?'], 'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.', 'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.'], 'nucleus': ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.', 'Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'The nucleus acts like the sun and the electrons are like planets which revolve in fixed defined orbitals.', 'But what exactly are these paths or orbits in which the electrons revolve around the nucleus?', 'The nucleus contains positive protons and the electrons revolving around in fixed orbitals.', 'Or is it that the electrons are randomly scattered in fixed orbitals around the nucleus?', 'But how exactly are the electrons distributed in fixed orbitals around the nucleus?'], 'defined': ['Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.', 'the planets always encircle the sun in defined paths.'], 'fixed defined orbitals': ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.', 'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.', 'The nucleus acts like the sun and the electrons are like planets which revolve in fixed defined orbitals.', 'So we can name fixed defined orbitals alphabetically or we can even number fixed defined orbitals.', 'And what if we want to number fixed defined orbitals?'], 'called': ['the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'the next legendary scientist in our list called Niels Bohr made a few additional explanations to describe the atomic structure.', 'The postulates put forward by the next legendary scientist in our list called Niels Bohr were as follows.', 'Firstly, only certain special orbits called discrete orbits of electrons are allowed inside the atom.', 'slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'orbits': ['Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'Firstly, only certain special orbits called discrete orbits of electrons are allowed inside the atom.', 'But what exactly are these paths or orbits in which the electrons revolve around the nucleus?'], 'niels bohr': ['the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'the next legendary scientist in our list called Niels Bohr made a few additional explanations to describe the atomic structure.', 'The postulates put forward by the next legendary scientist in our list called Niels Bohr were as follows.', 'slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'subatomic particle': ['a famous English physicist Sir James Chadwick found that one more subatomic particle had a mass almost equivalent to that of the proton.', 'one more subatomic particle was later named as neutron, denoted by the letter N. Does now we have the complete design of an atom?', 'Astonishingly, one more subatomic particle had no charge.', "And what about one more subatomic particle's charge?"], 'different path': ['We never find any planet jumping to a different path all of a sudden, right?'], 'solar system': ['Yes, our solar system appears somewhat like this.', 'Do you know how our solar system is?'], 'slight modifications': ['slight modifications were made by the next legendary scientist in our list called Niels Bohr.', 'Not really, the hypothesis put forth by Rutherford just needed slight modifications.'], 'next legendary scientist': ['the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'the next legendary scientist in our list called Niels Bohr made a few additional explanations to describe the atomic structure.', 'The postulates put forward by the next legendary scientist in our list called Niels Bohr were as follows.', 'slight modifications were made by the next legendary scientist in our list called Niels Bohr.'], 'electrons revolve': ['In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.', 'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.', 'But what exactly are these paths or orbits in which the electrons revolve around the nucleus?'], 'name energy levels': ['Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.'], 'certain special orbits': ['Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'Firstly, only certain special orbits called discrete orbits of electrons are allowed inside the atom.'], 'electron': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'], 'atomic model': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.", "However, Rutherford's atomic model was not very appropriate theoretically."], 'planets': ['The nucleus acts like the sun and the electrons are like planets which revolve in fixed defined orbitals.', 'Now here, the sun is stationary at the centre while the planets revolve around the sun.', 'But have you noticed that the planets always revolve in fixed paths?', 'the planets always encircle the sun in defined paths.'], 'rutherford': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.", 'Not really, the hypothesis put forth by Rutherford just needed slight modifications.', "However, Rutherford's atomic model was not very appropriate theoretically.", "That means the hypothesis put forth by Rutherford's was also incorrect."], 'few additional explanations': ['the next legendary scientist in our list called Niels Bohr made a few additional explanations to describe the atomic structure.']}

# %%
intersection_key = intersection(bertsum_key,ss_key)

# %%
intersection_key
# Out:
# ['energy',
#  'nucleus',
#  'electron',
#  'rutherford',
#  'atomic model',
#  'niels bohr',
#  'slight modifications',
#  'next legendary scientist']

# %%
import spacy
from spacy import displacy

NER = spacy.load("en_core_web_sm")

raw_text="Cells are the smallest living units of an organism. All cells have three things in common, no matter what type of cell they are. All cells have a cell membrane, which separates the inside of the cell from its environment. Uculoplasm, which is a jelly-like fluid, and DNA, which is the cell's genetic material. There are two broad categories of cells. The first category is eukaryotic cells. They have organelles, which include the nucleus and other special parts. Eukaryotic cells are more advanced complex cells, such as those found in plants and animals. The second category is prokaryotic cells. They don't have a nucleus or membrane-enclosed organelles. They do have genetic material, but it's not contained within a nucleus. Prokaryotic cells are always one cell, or unicellular organisms, such as bacteria. So what are organelles? Organelles means little organ. Organelles are the specialized parts of a cell that have unique jobs to perform. Let's start with the nucleus, the control center of the cell. The nucleus contains DNA, or genetic material. DNA dictates what the cell is going to do and how it's going to do it. Chromatin is the tangled, spread-out form of DNA found inside the nuclear membrane. When a cell is ready to divide, DNA condenses into structures known as chromosomes. The nucleus also contains a nucleolus, which is a structure where ribosomes are made. Where ribosomes leave the nucleus, they will have the important job of synthesizing or making proteins. Outside the nucleus, the ribosomes and the rest of the organelles float around in cytoplasm, which is the jelly-like substance. Ribosomes may wander freely within the cytoplasm or attach to the endoplasmic reticulum, sometimes abbreviated as ER. There are two types of ER. Rough ER has ribosomes attached to it, and smooth ER doesn't have ribosomes attached to it. The endoplasmic reticulum is a membrane-enclosed passageway for transporting materials, such as the proteins synthesized by ribosomes. And other materials emerge from the endoplasmic reticulum in small vesicles, where the Golgi apparatus, sometimes called the Golgi body, receives them. As proteins move through the Golgi body, they're customized into forms that the cell can use. The Golgi body does this by folding the proteins into usable shapes, or adding other materials onto them, such as lipids, or carbohydrates. Vacuoles are sac-like structures that store different materials. Here in this plant cell, the central vacuole stores water. Going back to the animal cell, you will see an organell called a lysosome. Vesomes are the garbage collectors that take in damaged or worn-out cell parts. They are filled with enzymes that break down this cellular debris. The mitochondrion is an organell that is the powerhouse for both animal and plant cells. During a process called cellular respiration, the mitochondria make ATP molecules that provide the energy for all of the cell's activities. Cells that need more energy have more mitochondria. Meanwhile, the cell maintains its shape through a cytoskeleton. The cytoskeleton includes the thread-like microfilaments, which are made of protein, microtubules, which are thin hollow tubes. Some organisms, such as plants, that are photoautotrophic, meaning they capture sunlight for energy, have cells with an organell called a chloroplast. The chloroplast is where photosynthesis happens. It's green because it has a green pigment called chlorophyll. Plant cells also have a cell wall outside of their cell membranes that shape, support, and protect the plant cell. Animal cells never have a cell wall. There are many other unique structures that only some cells have. Here are just a few. In humans, for example, the respiratory tract is lined with cells that have cilia. These are microscopic, hair-like projections that can move in waves. This feature helps trap inhaled particles in the air and expels them when you cough. Another unique feature in some cells is flagella. Some bacteria have flagella. A flagellum is like a little tail that can help a cell move or propel itself. The only human cell that has a flagellum is a sperm cell. In summary, remember, eukaryotic cells are plant and animal cells with a nucleus and membrane-enclosed organelles. All prokaryotic cells are unicellular organisms without these things. All cells have a cell membrane, cytoplasm, and genetic material. And even though only plant cells have chloroplasts, both plant and animal cells have mitochondria."
text1= NER(raw_text)

for word in text1.ents:
    print(word.text,word.label_)
# Out:
# three CARDINAL
# two CARDINAL
# first ORDINAL
# second ORDINAL
# one CARDINAL
# Chromatin PERSON
# ER ORG
# two CARDINAL
# ER ORG
# ER ORG
# ER ORG

# %%
bertsum_map.keys()
# Out:
# dict_keys(['vitamins', 'body', 'blood', 'helps', 'cells', 'random out-of-order alphabet', 'vitamin a', 'heart disorders', 'nerve damage', 'shape bones', 'k. no', 'white blood cells', 'stores vitamins', 'fat-soluble vitamins', 'vitamin variety', 'problems', 'range', 'lipid-soluble', 'a', 'c', 'b', 'e', 'd'])

# %%
bertsum_map.values()
# Out:
# dict_values([['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.', 'Once inside the system, these foods are digested, and the vitamins within them are taken up directly by the bloodstream.'], ['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between them determines how the body transports and stores vitamins and gets rid of the excess.', "Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], ["Because fat-soluble vitamins can't make use of the blood's watery nature, they need something else to move them around."], ["Vitamin A helps make white blood cells, key in the body's defense, helps shape bones, and improves vision by keeping the cells of the eye in check."], ["Vitamin A helps make white blood cells, key in the body's defense, h
# ...

# %%
result_bert = {key: bertsum_map[key] for key in bertsum_map if key in intersection_key}

# %%
result_bert
# Out:
# {'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  'nucleus': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'],
#  'electron': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  'rutherford': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
# ...

# %%
result_ss = {key: ss_map[key] for key in ss_map if key in intersection_key}

# %%
result_ss
# Out:
# {'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.',
#   'Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.',
#   'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.',
#   'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.'],
#  'nucleus': ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.',
# ...

# %%
result_bert.values()
# Out:
# dict_values([['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'], ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'], ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'], ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."], ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."], ['slight modifications were made by the next
# ...

# %%
result_ss.values()
# Out:
# dict_values([['Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid of the excess.', "Vitamins're the body's builders, defenders, and maintenance workers, helping the body's to build muscle and bone, make use of nutrients, capture and use energy, and heal wounds.", 'Vitamins are organic compounds we need to ingest in small amounts to keep functioning.', 'So how does the body get vitamins from out there into here?'], ["The body treats these parts like a pantry, storing fat-soluble vitamins there and rationing fat-soluble vitamins out when needed, meaning we shouldn't overload on this type of vitamin because The body is generally well stocked.", 'Vitamins come in two types, lipid-soluble and water-soluble, and the difference between two types, lipid-soluble and water-soluble determines how the body transports and stores vitamins and gets rid 
# ...

# %%
type(result_ss.values())
# Out:
# dict_values

# %%
result_ss
# Out:
# {'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.',
#   'Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.',
#   'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.',
#   'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.'],
#  'nucleus': ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.',
# ...

# %%
temp_list = list(result_bert.values())+list(result_ss.values())
temp_list
# Out:
# [['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'],
#  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
#  ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
# ...

# %%
temp_list = set(temp_list)
temp_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e1d43f23b2ed> in <cell line: 1>()
# ----> 1 temp_list = set(temp_list)
#       2 temp_list
#
# TypeError: unhashable type: 'list'

# %%
temp_list = list(result_bert.values())
temp_list
# Out:
# [['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'],
#  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
#  ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
# ...

# %%
len(list(result_bert.values()))
# Out:
# 8

# %%
temp = []
for i in list(result_bert.values()):
  for j in i:
    temp.append(j)

# %%
temp
# Out:
# ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#  'Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#  'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.',
#  'Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#  "Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.",
#  "Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.",
# ...

# %%
for i in list(result_ss.values()):
  for j in i:
    temp.append(j)

# %%
temp
# Out:
# ['Plants have tubes called xylum, located in the stems through which the water from the ground is sucked into the leaves.',
#  'a green color component called chloroplasts is responsible for the green color of plants and leaves.',
#  "Well, this video elaborates the process of photosynthesis by which plants make plants's own food.",
#  "Photosynthesis is the process used by plants to make plants's own food or in more complex terms.",
#  'Photosynthesis is the conversion of light energy into chemical energy by plants.',
#  'chemical energy is used by plants for growth and nourishment.',
#  "Glucose is used by the plants for the plants's growth.",
#  "Do kids know how plants make plants's own food?",
#  "The oxygen that is released is used by human beings to breathe during human beings's respiration process ever wondered why the process of photosynthesis is called photosynthesis?",
# ...

# %%
temp = set(temp)

# %%
def sorting(bertsum_key, bertsum_map, ss_key, ss_map):
  intersection_key = intersection(bertsum_key,ss_key)
  result_bert = {key: bertsum_map[key] for key in bertsum_map if key in intersection_key}
  result_ss = {key: ss_map[key] for key in ss_map if key in intersection_key}
  temp_list = list(result_bert.values())+list(result_ss.values())
  temp_list

# %%
temp
# Out:
# {'And when atoms gain a positive or negative charge through the transfer of electrons, a measurable electric field will form.',
#  'Electromagnetism is a branch of physics that studies the interactions between electric and magnetic fields.',
#  'Electromagnetism, or the electromagnetic force, is one of the four fundamental forces of nature.',
#  'On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.',
#  'On the other are short, high-frequency wavelengths, ultraviolet, ex, and gamma radiation.',
#  "The intensity of waves of electromagnetic energy or radiation is determined by waves of electromagnetic energy or radiation's frequency.",
# ...

# %%
result_bert
# Out:
# {'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  'nucleus': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.'],
#  'electron': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.'],
#  'rutherford': ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."],
# ...

# %%
result_ss
# Out:
# {'energy': ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.',
#   'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.',
#   'Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.',
#   'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.',
#   'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.'],
#  'nucleus': ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.',
# ...

# %%
result_ss.items()
# Out:
# dict_items([('energy', ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'the next legendary scientist in our list called Niels Bohr suggested that the electrons revolving in fixed defined orbitals do not radiate energy.', 'Now this is justified when we use the name energy levels because the name energy levels indicates that each shell has got a defined energy level.', 'Secondly, while revolving in only certain special orbits called discrete orbits of electrons, the electrons do not radiate energy.', 'That means when the electrons revolve in fixed defined orbitals, the electrons do not liberate any form of energy.']), ('nucleus', ['In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.', 'Now if the electron contin
# ...

# %%
'waves' in list(result_ss.keys())
# Out:
# True

# %%
type(result_ss)
# Out:
# dict

# %%
result_ss['waves']
# Out:
# ['On one end are long, low-frequency radio waves that broadcast television and radio signals, micro waves that carry telephone signals and cook food, and infrared waves emitted by fires.',
#  "The intensity of waves of electromagnetic energy or radiation is determined by waves of electromagnetic energy or radiation's frequency."]

# %%
temp_list = ['word']
temp_list
# Out:
# ['word']

# %%
for key,sent in result_bert.items():
  print("keyword : ",key)
  print("sentence : ",sent )
# Out:
# keyword :  energy
# sentence :  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.']
# keyword :  nucleus
# sentence :  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.', 'In the center lies the nucleus having positively charged protons and neutral neutrons, while the negatively charged electrons revolve in fixed orbitals around The nucleus.']
# keyword :  electron
# sentence :  ['Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.']
# keyword :  rutherford
# sentence :  ["Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms."]
# ...

# %%
sentence_keyword_dicts = {}
for key,sent in result_bert.items():
  if sent[0] in list(sentence_keyword_dicts.keys()):
    sentence_keyword_dicts[sent[0]].append(key)
  else:
    sentence_keyword_dicts[sent[0]] = [key]

# %%
sentence_keyword_dicts.values()
# Out:
# dict_values([['energy', 'nucleus', 'electron'], ['rutherford', 'atomic model'], ['niels bohr', 'slight modifications', 'next legendary scientist']])

# %%
sentence_keyword_dicts
# Out:
# {'Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.': ['energy',
#   'nucleus',
#   'electron'],
#  "Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.": ['rutherford',
#   'atomic model'],
#  'slight modifications were made by the next legendary scientist in our list called Niels Bohr.': ['niels bohr',
#   'slight modifications',
#   'next legendary scientist']}

# %%
for key,sent in result_ss.items():
  if sent[0] in list(sentence_keyword_dicts.keys()):
    sentence_keyword_dicts[sent[0]].append(key)
  else:
    sentence_keyword_dicts[sent[0]] = [key]

# %%
sentence_keyword_dicts
# Out:
# {'Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.': ['energy',
#   'nucleus',
#   'electron',
#   'energy',
#   'electron'],
#  "Rutherford's atomic model was quite commendable when it came to explaining the structure of atoms.": ['rutherford',
#   'atomic model',
#   'atomic model',
#   'rutherford'],
#  'slight modifications were made by the next legendary scientist in our list called Niels Bohr.': ['niels bohr',
#   'slight modifications',
#   'next legendary scientist',
#   'slight modifications'],
#  'In that case, we use the letter N in lower case and write fixed defined orbitals as the letter N equals 1, the letter N equals 2, N equals 3 and so on, beginning from the 1 next to The nucleus.': ['nucleus'],
# ...

# %% [markdown]
# # QUESTION GENERATION

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.1 MB/s eta 0:00:00
# ...

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer
model_name = 'mrm8488/t5-base-finetuned-question-generation-ap'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
# Out:
# ...
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# ...
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# /usr/local/lib/python3.9/dist-packages/transformers/models/auto/modeling_auto.py:1322: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# ...

# %%
def get_question(answer, context, max_length=64):
  input_text = "answer: %s  context: %s </s>" % (answer, context)
  features = tokenizer([input_text], return_tensors='pt')

  output = model.generate(input_ids=features['input_ids'],
               attention_mask=features['attention_mask'],
               max_length=max_length)

  return tokenizer.decode(output[0])

# %%
question_answer = {}
for sent, keylist in sentence_keyword_dicts.items():
  for keyword in keylist:
    context = sent
    answer = keyword
    question = get_question(answer, context)
    question_answer[question] = answer

# %%
question_answer
# Out:
# {'<pad> question: What does the electron radiate?</s>': 'energy',
#  '<pad> question: What will all the energy of the electron fall into?</s>': 'nucleus',
#  '<pad> question: What is the main source of energy that will eventually get over and fall into the nucleus?</s>': 'electron',
#  '<pad> question: Whose atomic model was laudable?</s>': 'rutherford',
#  '<pad> question: What model did Rutherford use to explain the structure of atoms?</s>': 'atomic model',
#  '<pad> question: Who was the next scientist to be on our list?</s>': 'niels bohr',
#  '<pad> question: What was made by Niels Bohr?</s>': 'slight modifications',
#  '<pad> question: Who was Niels Bohr?</s>': 'next legendary scientist',
#  '<pad> question: What is the first letter next to?</s>': 'nucleus',
#  '<pad> question: Who suggested that electrons revolving in fixed defined orbitals do not radiate energy?</s>': 'niels bohr',
#  "<pad> question: What is Niels Bohr's title?</s>": 'next legendary scientist'}

# %% [markdown]
# # Distractor Generation

# %%
# !pip install sense2vec
# !wget https://github.com/explosion/sense2vec/releases/download/v1.0.0/s2v_reddit_2015_md.tar.gz
# !tar -xvf  s2v_reddit_2015_md.tar.gz

# load sense2vec vectors
from sense2vec import Sense2Vec
s2v = Sense2Vec().from_disk('s2v_old')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.8 MB/s eta 0:00:00
# ...
# --2023-04-17 04:58:09--  https://github.com/explosion/sense2vec/releases/download/v1.0.0/s2v_reddit_2015_md.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import string
def edits(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz '+string.punctuation
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

# %%
import collections
OrderedDict = collections.OrderedDict()
def sense2vec_get_words(word,s2v):
    output = []

    word_preprocessed =  word.translate(word.maketrans("","", string.punctuation))
    word_preprocessed = word_preprocessed.lower()

    word_edits = edits(word_preprocessed)

    word = word.replace(" ", "_")

    sense = s2v.get_best_sense(word)
    most_similar = s2v.most_similar(sense, n=15)

    compare_list = [word_preprocessed]
    for each_word in most_similar:
        append_word = each_word[0].split("|")[0].replace("_", " ")
        append_word = append_word.strip()
        append_word_processed = append_word.lower()
        append_word_processed = append_word_processed.translate(append_word_processed.maketrans("","", string.punctuation))
        if append_word_processed not in compare_list and word_preprocessed not in append_word_processed and append_word_processed not in word_edits:
            output.append(append_word.title())
            compare_list.append(append_word_processed)


    out = list(OrderedDict.fromkeys(output))

    return out

# %%
def get_options(answer,s2v):
    distractors =[]

    try:
        distractors = sense2vec_get_words(answer,s2v)
        if len(distractors) > 0:
            print(" Sense2vec_distractors successful for word : ", answer)
            return distractors
    except:
        print (" Sense2vec_distractors failed for word : ",answer)


    return distractors

# %%
# !pip install -U sentence-transformers
from sentence_transformers import SentenceTransformer
model= SentenceTransformer('all-MiniLM-L12-v2')

def get_answer_and_distractor_embeddings(answer,candidate_distractors):
  answer_embedding = model.encode([answer])
  distractor_embeddings = model.encode(candidate_distractors)
  return answer_embedding,distractor_embeddings
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=73e3e765be4eb749433fe44125e3c2c53fe894b56ddb7129abbfad57ab9b8e05
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# ...

# %%
from typing import List, Tuple
import itertools
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def mmr(doc_embedding: np.ndarray,
        word_embeddings: np.ndarray,
        words: List[str],
        top_n: int = 5,
        diversity: float = 0.9) -> List[Tuple[str, float]]:

    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)

    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [(words[idx], round(float(word_doc_similarity.reshape(1, -1)[0][idx]), 4)) for idx in keywords_idx]

# %%
def get_distractors(orginal_word):
  distractors = get_options(orginal_word, s2v)
  print(distractors)
  distractors.insert(0,orginal_word)
  answer_embedd, distractor_embedds = get_answer_and_distractor_embeddings(orginal_word,distractors)
  final_distractors = mmr(answer_embedd,distractor_embedds,distractors,4)
  filtered_distractors = []
  for dist in final_distractors:
    filtered_distractors.append (dist[0])

  Answer = filtered_distractors[0]
  Filtered_Distractors =  filtered_distractors[1:]

  print (Answer)
  print ("------------------->")
  for k in Filtered_Distractors:
    print (k)

  return Filtered_Distractors

# %%
import random
def reorder_options(Answer, Filtered_Distractors):
  ans_pos = random.randint(0,3)
  options = []
  j=0
  for i in range(4):
    if i != ans_pos:
      options[i] = Filtered_Distractors[j]
      j+=1
    else:
      options[i] = Answer
  return options

# %%
options = reorder_options(Answer, Filtered_Distractors)
# Out:
# range(0, 3)

# %%
# !pip install --upgrade pip  # ensures that pip is current
# !git clone https://github.com/google-research/bleurt.git
# !cd bleurt
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'bleurt'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 134 (delta 0), reused 17 (delta 0), pack-reused 116
# Receiving objects: 100% (134/134), 31.28 MiB | 37.03 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !python -m unittest bleurt.score_test
# !python -m unittest bleurt.score_not_eager_test
# !python -m unittest bleurt.finetune_test
# !python -m unittest bleurt.score_files_test

# %%
# Downloads the BLEURT-base checkpoint.
wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip .
unzip BLEURT-20.zip

# Runs the scoring.
python -m bleurt.score_files \
  -candidate_file=bleurt/test_data/candidates \
  -reference_file=bleurt/test_data/references \
  -bleurt_checkpoint=BLEURT-20

# %%
# !pip install bert_score
from bert_score import score
# !git clone https://github.com/Tiiiger/bert_score

references = ["Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus."]
candidates = ["Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nuclei."]
P,R,F1 = score(candidates, references, lang = 'en', verbose = True)
print(P, R, F1)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# fatal: destination path 'bert_score' already exists and is not an empty directory.
# ...
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
references = ["Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus.", "Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus."]
candidates = ["Now if the proton continuously keeps radiating energy, then ultimately all the energy of the proton will get over and all the energy of the proton will fall into the nucleus.","Now if the photon continuously keeps radiating energy, then ultimately all the energy of the photon will get over and all the energy of the photon will fall into the nucleus.","Now if the positron continuously keeps radiating energy, then ultimately all the energy of the positron will get over and all the energy of the positron will fall into the nucleus.","Now if the particle continuously keeps radiating energy, then ultimately all the energy of the particle will get over and all the energy of the particle will fall into the nucleus.","Now if the atom continuously keeps radiating energy, then ultimately all the energy of the atom will get over and all the energy of the atom will fall into the nucleus.","Now if the hydrogen atom continuously keeps radiating energy, then ultimately all the energy of the hydrogen atom will get over and all the energy of the hydrogen atom will fall into the nucleus.","Now if the photons continuously keeps radiating energy, then ultimately all the energy of the photons will get over and all the energy of the photons will fall into the nucleus.","Now if the neutron continuously keeps radiating energy, then ultimately all the energy of the neutron will get over and all the energy of the neutron will fall into the nucleus.","Now if the neutrino continuously keeps radiating energy, then ultimately all the energy of the neutrino will get over and all the energy of the neutrino will fall into the nucleus.","Now if the Muon continuously keeps radiating energy, then ultimately all the energy of the Muon will get over and all the energy of the Muon will fall into the nucleus.","Now if the electromagnetic field continuously keeps radiating energy, then ultimately all the energy of the electromagnetic field will get over and all the energy of the electromagnetic field will fall into the nucleus.","Now if the nucleus continuously keeps radiating energy, then ultimately all the energy of the nucleus will get over and all the energy of the nucleus will fall into the nucleus.", "Now if the magnetic moment continuously keeps radiating energy, then ultimately all the energy of the magnetic moment will get over and all the energy of the magnetic moment will fall into the nucleus."]

P,R,F1 = score(candidates, references, lang = 'en', verbose = True)
print(P, R, F1)
# Out:
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
from bleurt import score

checkpoint = "bleurt/test_checkpoint"
references = ["Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleus."]
candidates = ["Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nuclei.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the atom.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the electron.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the proton.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the electrons.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the molecule.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the neutrons.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the other atoms.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the atoms.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the nucleons.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the electron cloud.","Now if the electron continuously keeps radiating energy, then ultimately all the energy of the electron will get over and all the energy of the electron will fall into the hydrogen atom."]

scorer = score.BleurtScorer(checkpoint)
scores = scorer.score(references=references, candidates=candidates)
assert isinstance(scores, list) and len(scores) == 1
print(scores)

# %%
for question,qna in question_answer.items():
  print("****************************************************************")
  print(question)
  print(qna)
  print(qna)
  try:
    options = get_distractors(qna)
    print(options)
  except:
    print("NO DISTRACTORS GENERATED")
# Out:
# ****************************************************************
# <pad> question: What does the electron radiate?</s>
# energy
# energy
# []
# NO DISTRACTORS GENERATED
# ****************************************************************
# <pad> question: What will all the energy of the electron fall into?</s>
# nucleus
# nucleus
#  Sense2vec_distractors successful for word :  nucleus
# ['Nuclei', 'Atom', 'Electron', 'Proton', 'Electrons', 'Molecule', 'Protons', 'Molecules', 'Neutrons', 'Other Atoms', 'Atoms', 'Nucleons', 'Electron Cloud', 'Hydrogen Atom']
# nucleus
# ------------------->
# Electron Cloud
# Molecules
# Hydrogen Atom
# ['Electron Cloud', 'Molecules', 'Hydrogen Atom']
# ****************************************************************
# <pad> question: What is the main source of energy that will eventually get over and fall into the nucleus?</s>
# electron
# electron
#  Sense2vec_distractors successful for word :  electron
# ...

# %%
for question,qna in question_answer.items():
  print("****************************************************************")
  print(question)
  print(qna)
  print(qna)
  try:
    options = get_distractors(qna)
    print(options)
  except:
    print("NO DISTRACTORS GENERATED")
# Out:
# ****************************************************************
# <pad> question: What can pass through the human body?</s>
# waves
# waves
#  Sense2vec_distractors successful for word :  waves
# ['Big Wave', 'Large Wave', 'Giant Wave', 'Random Directions', 'Whirlpools', 'Storms', 'Great Distance']
# waves
# ------------------->
# Random Directions
# Whirlpools
# Great Distance
# ['Random Directions', 'Whirlpools', 'Great Distance']
# ****************************************************************
# <pad> question: What kind of waves can pass through the human body?</s>
# low-frequency waves
# low-frequency waves
#  Sense2vec_distractors failed for word :  low-frequency waves
# []
# NO DISTRACTORS GENERATED
# ****************************************************************
# <pad> question: What is one of the four fundamental forces of nature?</s>
# electromagnetism
# electromagnetism
#  Sense2vec_distractors successful for word :  electromagnetism
# ...

# %%
for question,qna in question_answer.items():
  print("****************************************************************")
  print(question)
  print(qna)
  print(qna)
  try:
    options = get_distractors(qna)
    print(options)
  except:
    print("NO DISTRACTORS GENERATED")
# Out:
# ****************************************************************
# <pad> question: What does the body transport and store?</s>
# vitamins
# vitamins
#  Sense2vec_distractors successful for word :  vitamins
# ['Multivitamin', 'Vitamin Supplements', 'Supplements', 'Fish Oil', 'Micronutrients', 'Micro Nutrients', 'Antioxidants', 'Essential Nutrients', 'Probiotics']
# vitamins
# ------------------->
# Fish Oil
# Probiotics
# Antioxidants
# ['Fish Oil', 'Probiotics', 'Antioxidants']
# ****************************************************************
# <pad> question: What organ stores and transports vitamins?</s>
# body
# body
#  Sense2vec_distractors successful for word :  body
# ['Internal Organs', 'Muscles', 'Muscle Tissue', 'Bodies', 'Fatty Tissue', 'Musculature', 'Brain', 'Blood Circulation']
# body
# ------------------->
# Blood Circulation
# Musculature
# Fatty Tissue
# ['Blood Circulation', 'Musculature', 'Fatty Tissue']
# ...

# %%
for question,qna in question_answer.items():
  print("****************************************************************")
  print(question)
  print(qna)
  print(qna)
  try:
    options = get_distractors(qna)
    print(options)
  except:
    print("NO DISTRACTORS GENERATED")
# Out:
# ****************************************************************
# <pad> question: What type of plants don't need photosynthesis?</s>
# plants
#  Sense2vec_distractors successful for word :  plants
# ['Algae', 'Plant Life', 'Other Plant', 'Soil', 'Crops', 'Grasses', 'Fungi', 'Insects']
# plants
# ------------------->
# Insects
# Soil
# Fungi
# ['Insects', 'Soil', 'Fungi']
# ****************************************************************
# <pad> question: What process does venous fly traps not need to grow?</s>
# photosynthesis
#  Sense2vec_distractors successful for word :  photosynthesis
# ['Photosynthesize', 'Cellular Respiration', 'Organic Matter', 'Carbon Dioxide', 'Plant Growth', 'Atmospheric Oxygen', 'Oxygen', 'Biomass', 'Photosynthesizing', 'Plants', 'Organic Material', 'Cyanobacteria', 'Chloroplasts', 'Nitrogen', 'Organic Compounds']
# photosynthesis
# ------------------->
# Organic Material
# Nitrogen
# Biomass
# ['Organic Material', 'Nitrogen', 'Biomass']
# ...

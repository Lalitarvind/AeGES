# %%
# !python3 -m nltk.downloader bllip_wsj_no_aux
# Out:
# /usr/lib/python3.9/runpy.py:127: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package bllip_wsj_no_aux to /root/nltk_data...
# [nltk_data]   Unzipping models/bllip_wsj_no_aux.zip.

# %%
# !pip3 install bllipparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bllipparser
#   Downloading bllipparser-2021.11.7.tar.gz (554 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.1/554.1 KB 30.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from bllipparser) (1.16.0)
# Building wheels for collected packages: bllipparser
#   Building wheel for bllipparser (setup.py) ... done
#   Created wheel for bllipparser: filename=bllipparser-2021.11.7-cp39-cp39-linux_x86_64.whl size=8475046 sha256=9c6da1736d0e73b1510f2f1d87e6a36f89501eb375039ec38ca1dfe096c20dde
#   Stored in directory: /root/.cache/pip/wheels/de/3c/8c/991c3155cb7010f4a02dd68b2e717ae7d8a3e97278a154c3f9
# Successfully built bllipparser
# Installing collected packages: bllipparser
# Successfully installed bllipparser-2021.11.7

# %%
from nltk.data import find
from bllipparser import RerankingParser

# %%
model_dir = find('models/bllip_wsj_no_aux').path
parser = RerankingParser.from_unified_model_dir(model_dir)

# %%
ambi = parser.parse("Which property do these three objects have in common?")
# clear = parser.parse("What is the temperature of the air on a cold, rainy day?")
# clear = parser.parse("What is the probability that a goat produced by this cross will be homozygous dominant for the myotonia congenita gene?")
# clear = parser.parse("What does pollen help a plant do?")
clear = parser.parse("What is the expected ratio of offspring with a woolly fleece to offspring with a hairy fleece?")
#print(best.get_reranker_best())
print(ambi.get_parser_best())
print(clear.get_parser_best())
# Out:
# -96.132718906075 -32.203381134629 (S1 (SBARQ (WHNP (WDT Which) (NN property)) (SQ (VBP do) (NP (DT these) (CD three) (NNS objects)) (VP (VB have) (PP (IN in) (ADJP (JJ common))))) (. ?)))
# -205.004513098020 -63.318347330896 (S1 (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (VBN expected) (NN ratio)) (PP (IN of) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ woolly) (NN fleece))))) (PP (TO to) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ hairy) (NN fleece)))))))) (. ?)))

# %%
s = str(clear.get_parser_best())
s = s[s.find('('):]
s
# Out:
# '(S1 (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (VBN expected) (NN ratio)) (PP (IN of) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ woolly) (NN fleece))))) (PP (TO to) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ hairy) (NN fleece)))))))) (. ?)))'

# %%
import bllipparser
tree = bllipparser.Tree(s)
tree.pretty_string()
print(tree.pretty_string())
# Out:
# (S1 (SBARQ (WHNP (WP What))
#      (SQ (VP (VBZ is)
# 	  (NP (NP (DT the) (VBN expected) (NN ratio))
# 	   (PP (IN of)
# 	    (NP (NP (NN offspring))
# 	     (PP (IN with) (NP (DT a) (JJ woolly) (NN fleece)))))
# 	   (PP (TO to)
# 	    (NP (NP (NN offspring))
# 	     (PP (IN with) (NP (DT a) (JJ hairy) (NN fleece))))))))
#      (. ?)))

# %%
import bllipparser
from operator import itemgetter

# %%
DEBUG = False

# %%
class POSTree(object):

    class Node(object):
        def __init__(self, token):
            self.token = token
            self.first_child = None
            self.next_sibling = None

        def __repr__(self):
            return '<%s>' % (self.token,)

    def __init__(self, text):

        self.raw_text = text
        self.text = text.replace('\n', '')
        self.text_length = len(self.text)
        self.text_pointer = 0
        self.words = []
        self.root = self.__create_tree()
        self.question = ' '.join(self.__gather_word(self.root))
        self.VB_TAG = ('VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'MD')
        self.VB_WORD = ('do', 'does', 'can', 'could', 'would', 'should',
                'might', 'has', 'have', "'ve", 'is', "'s", 'are', "'re", 'was', 'were')

    def __create_tree(self):
        parent = None
        token = self.__next_token()
        if token == '(':
            token = self.__next_token()
            parent = self.Node(token)
            parent.first_child = self.__create_tree().
            child = parent.first_child
            if child != None:
                while True:
                    child.next_sibling = self.__create_tree()
                    child = child.next_sibling
                    if child == None:
                        break
        elif token != ')':
            parent = self.Node(token.lower())
            self.words.append(token.lower())

        return parent

    def __next_token(self):
        end = self.text_pointer
        while end < self.text_length and self.text[end] == ' ':
            end += 1

        if end == self.text_length:
            return None

        if self.text[end] in ('(', ')'):
            token = self.text[end]
            end += 1
        else:
            start = end
            end += 1
            while end < self.text_length and self.text[end] not in ('(', ')', ' '):
                end += 1
            token = self.text[start:end]
        self.text_pointer = end
        return token

    def first_order_traverse(self):
        self.__first_order_traverse(self.root)
    def __first_order_traverse(self, tree):
        if tree != None:
            print(tree.token)
            self.__first_order_traverse(tree.first_child)
            if tree.first_child != None:
                child = tree.first_child.next_sibling
                while child != None:
                    self.__first_order_traverse(child)
                    child = child.next_sibling

    def __delete_period(self):
        child = self.root.first_child.first_child
        assert(child.token != '.')
        while child.next_sibling.token != '.':
            child = child.next_sibling
        child.next_sibling = None

    def __check_PP(self, prenode, node):
        while node != None and node.token in ('PP', ',', 'SBAR'):
            prenode = node
            node = node.next_sibling
        return prenode, node

    def adjust_order(self):
        try:
            child = self.root.first_child
            if child.token == 'FRAG' and ' '.join(self.words[:2]) == 'how many':
                words = ['there', 'are', '**blank**'] + self.words[2:-1]
                return ' '.join(words)

            self.__delete_period()
            assert(child.next_sibling == None)
            if child.token == 'SQ':
                self.__adjust_SQ_question(child)
            elif child.token == 'SBARQ':
                prefirst = child
                first = child.first_child
                second = first.next_sibling
                if first.token == 'SQ' and second == None:
                    self.__adjust_SQ_question(first)
                elif (first.token in ('WHADJP', 'WHNP', 'WHADVP', 'WHPP')
                        and second.token == 'SQ'):
                    WH = self.__delete_tree(prefirst, first)
                    self.__adjust_SBARQ_question(WH, second)
                else:
                    raise ValueError('Unknown question structure!')
            elif child.token == 'SBAR':
                if (child.first_child.token == 'WHADJP'
                        and child.first_child.next_sibling.token == 'S'
                        and ' '.join(self.words[:2]) == 'how many'):
                    SQ = child.first_child.next_sibling
                    WH = self.__delete_tree(child, child.first_child)
                    self.__adjust_SBARQ_question(WH, SQ)
                else:
                    raise ValueError('Unknown question structure!')
            else:
                raise ValueError('Unknown question structure!')
            words = self.__gather_word(self.root)
            words = filter(lambda w: w != '', words)
            statement = ' '.join(words)
        except Exception as e:
            if DEBUG:
                print(self.question)
                print(self.raw_text)
            raise e
        return statement

    def __create_answer_node(self, before_text='', after_text=''):
        node = self.Node('A')
        answer = '**blank**'
        if before_text != '':
            answer = '%s %s' % (before_text, answer)
        if after_text != '':
            answer = '%s %s' % (answer, after_text)
        node.first_child = self.Node(answer)
        return node

    def __check_VB(self, node):
        if node.token in self.VB_TAG:
            return True
        if node.first_child.token in self.VB_WORD:
            node.token = 'VB'
            return True
        return False

    def __adjust_SQ_question(self, SQ):
        VB = SQ.first_child
        assert(self.__check_VB(VB))
        auxiliary = VB.first_child.token
        if auxiliary not in ('do', 'did', 'does'):
            answer = self.__create_answer_node(before_text=auxiliary)
        else:
            answer = self.__create_answer_node()

        # move answer after first NP
        NP = VB.next_sibling
        while NP.token != 'NP':
            NP = NP.next_sibling
        self.__insert_after(answer, NP)
        self.__delete_tree(SQ, VB)
        return SQ

    def __gather_word(self, tree):
        words = []
        def recursor(t):
            if t == None:
                return
            if t.first_child == None:
                words.append(t.token)
            else:
                recursor(t.first_child)
                sibling = t.first_child.next_sibling
                while sibling != None:
                    recursor(sibling)
                    sibling = sibling.next_sibling
        recursor(tree)
        return words

    def __tree_to_text(self, tree):
        words = []
        def recursor(t):
            if t == None:
                return
            if t.first_child == None:
                words.append(' '+t.token)
            else:
                words.append('('+t.token)
                recursor(t.first_child)
                sibling = t.first_child.next_sibling
                while sibling != None:
                    recursor(sibling)
                    sibling = sibling.next_sibling
                words.append(')')
        recursor(tree)
        return ''.join(words)

    def __convert_WH_to_answer(self, WH):
        words = self.__gather_word(WH)
        WH_text = ' '.join(words)
        if WH_text == 'how old':
            WH.first_child = self.__create_answer_node(after_text='years old')
        elif WH_text == 'why':
            WH.first_child = self.__create_answer_node(before_text='because')
        elif WH.token in ('WHADJP', 'WHADVP'):
            WH.first_child = self.__create_answer_node()
        elif WH.token == 'WHNP' or WH.token == 'WHPP' and WH.first_child.next_sibling.token == 'WHNP':
            parent = WH if WH.token == 'WHNP' else WH.first_child.next_sibling
            first = WH.first_child
            while first.token == 'WHNP':
                parent = first
                first = first.first_child
            if first.token == 'WHADJP':
                first.first_child = self.__create_answer_node()
            elif self.__tree_to_text(parent).startswith('(WHNP(WDT what)(NN color)(NN'):
                after_text = ' '.join(self.__gather_word(parent)).replace('what color ', '', 1)
                parent.first_child = self.__create_answer_node(after_text=after_text)
            else:
                parent.first_child = self.__create_answer_node()
        else:
            raise ValueError('Unknown WH structure!')
        return WH

    def __check_ADVP(self, prenode, node):
        while node != None and node.token == 'ADVP':
            prenode = node
            node = node.next_sibling
        return prenode, node

    def __delete_tree(self, prenode, node):
        if node == None:
            return node
        if prenode.first_child == node:
            prenode.first_child = node.next_sibling
        else:
            prenode.next_sibling = node.next_sibling
        node.next_sibling = None
        return node

    def __delete_node(self, prenode, node):
        if node == None:
            return node
        if prenode.first_child == node:
            if node.first_child == None:
                prenode.first_child = node.next_sibling
            else:
                prenode.first_child = node.first_child
                lc = node.first_child
                while lc.next_sibling != None:
                    lc = lc.next_sibling
                lc.next_sibling = node.next_sibling
                node.first_child = None
        else:
            if node.first_child == None:
                prenode.next_sibling = node.next_sibling
            else:
                prenode.next_sibling = node.first_child
                lc = node.first_child
                while lc.next_sibling != None:
                    lc = lc.next_sibling
                lc.next_sibling = node.next_sibling
                node.first_child = None
        node.next_sibling = None
        return node

    def __insert_after(self, srcnode, dstnode):
        assert(srcnode != None and dstnode != None)
        srcnode.next_sibling = dstnode.next_sibling
        dstnode.next_sibling = srcnode
        return srcnode

    def __insert_as_first_child(self, srcnode, dstnode):
        assert(srcnode != None and dstnode != None)
        srcnode.next_sibling = dstnode.first_child
        dstnode.first_child = srcnode
        return srcnode

    def __insert_as_last_child(self, srcnode, dstnode):
        assert(srcnode != None and dstnode != None)
        lc = dstnode.first_child
        if lc == None:
            self.__insert_as_first_child(srcnode, dstnode)
        else:
            while lc.next_sibling != None:
                lc = lc.next_sibling
            self.__insert_after(srcnode, lc)
        return srcnode

    def __adjust_SQ_in_SBARQ(self, SQ, WH):
        prefirst, first = self.__check_ADVP(SQ, SQ.first_child)

        # SQ = VP
        if first.token == 'VP':
            return SQ

        # SQ = NP + VP
        if (first.token == 'NP' and first.next_sibling != None
                and first.next_sibling.token == 'VP' and first.next_sibling.next_sibling == None):
            return SQ

        if not self.__check_VB(first):
            raise ValueError('First child of SQ in SBARQ is not VB*/MD')

        # process 's 're 've
        if first.first_child.token == "'s":
            first.first_child.token = 'is'
        elif first.first_child.token == "'re":
            first.first_child.token = 'are'
        elif first.first_child.token == "'ve":
            first.first_child.token = 'have'

        presecond, second = self.__check_ADVP(first, first.next_sibling)

        # SQ = VB* + [ADVP]
        if second == None:
            return SQ

        # process RB(not) and auxiliary do/does/did
        if second.token == 'RB' and second.first_child.token in ("n't", "not"):
            if first.first_child.token == 'ca':
                first.first_child.token = 'can not'
            else:
                first.first_child.token += ' not'
            self.__delete_tree(presecond, second)
            presecond, second = self.__check_ADVP(first, first.next_sibling)
        else:
            if first.first_child.token in ('do', 'does', 'did'):
                first.first_child.token = ''

        # SQ = VB*+PP/ADJP/VP
        if second.next_sibling == None and second.token in ('PP', 'ADJP', 'VP'):
            return SQ

        # SQ = VB* + NP
        #      |     |
        #     first second
        if second.token == 'NP' and second.next_sibling == None:
            fc = second.first_child

            # second = NP + ?
            #          |    |
            #          fc   sc
            if (fc.token == 'NP' and fc.next_sibling != None
                    and fc.next_sibling.next_sibling == None):
                sc = fc.next_sibling
                if ((sc.token == 'PP' and WH.token == 'WHADVP')
                        or (sc.token == 'PP' and sc.first_child.token == 'IN'
                            and sc.first_child.next_sibling == None)
                        or (sc.token == 'NP' and ' '.join(self.__gather_word(fc)) == 'there')
                        or (sc.token == 'ADJP')
                        or (sc.token == 'SBAR' and sc.first_child.token == 'WHADVP')):
                    self.__delete_node(presecond, second)
                    VB = self.__delete_tree(prefirst, first)
                    self.__insert_after(VB, fc)
                    return SQ
            VB = self.__delete_tree(prefirst, first)
            self.__insert_after(VB, second)
            return SQ

        # SQ = VB* + NP + ?
        #      |     |    |
        #    first second third
        if second.token == 'NP' and second.next_sibling != None:
            prethird, third = self.__check_ADVP(second, second.next_sibling)
            # SQ = VB* + NP + ADVP
            if third == None:
                VB = self.__delete_tree(prefirst, first)
                self.__insert_after(VB, second)
                return SQ

            if third.next_sibling == None:
                if ((third.token in ('ADJP', 'PP', 'NP', 'VP'))
                        or (third.token == 'S'
                            and self.__tree_to_text(third).startswith('(S(VP(TO to)(VP(VB'))):
                    VB = self.__delete_tree(prefirst, first)
                    self.__insert_after(VB, second)
                    return SQ

        raise ValueError('Unknown SQ structure in SBARQ!')

    def __prefix_by_to_WH(self, WH):
        BY = self.Node('BY')
        BY.first_child = self.Node('by')
        self.__insert_as_first_child(BY, WH)
        return WH

    def __insert_WH_into_SQ(self, WH, SQ):
        if self.words[0] == 'why':
            self.__insert_as_last_child(WH, SQ)
            return SQ

        prefirst, first = self.__check_ADVP(SQ, SQ.first_child)

        if first.next_sibling == None:
            # SQ = VP
            if first.token == 'VP':
                self.__insert_as_first_child(WH, SQ)
                return SQ

            # SQ = NP
            if first.token == 'NP':
                self.__insert_after(WH, first)
                return SQ

            # SQ = VB*
            if self.__check_VB(first):
                self.__insert_as_first_child(WH, SQ)
                return SQ

            raise ValueError('Unknown SQ structure!')

        presecond, second = self.__check_ADVP(first, first.next_sibling)

        # SQ = VB* + ADVP
        if self.__check_VB(first) and second == None:
            self.__insert_as_first_child(WH, SQ)
            return SQ

        # SQ = VB* + VP/PP/ADJP
        #      |     |
        #    first  second
        if (self.__check_VB(first) and second.next_sibling == None
                and second.token in ('VP', 'PP', 'ADJP')):
            self.__insert_as_first_child(WH, SQ)
            return SQ

        prethird, third = self.__check_ADVP(second, second.next_sibling)

        # SQ = NP + VB* + [ADVP]
        #      |    |
        #    first second
        if (first.token == 'NP' and self.__check_VB(second) and
                (second.next_sibling == None or third == None)):
            self.__insert_after(WH, second)
            return SQ

        # SQ = NP + VP
        #      |    |
        #    first second
        if (first.token == 'NP' and second.token == 'VP'
                and second.next_sibling == None):
            if WH.token in ('WHNP', 'WHADJP'):
                self.__insert_as_first_child(WH, SQ)
                return SQ
            if WH.token  == 'WHPP':
                self.__insert_after(WH, second)
                return SQ

        if third == None:
            raise ValueError('Unknown SQ structure!')

        # SQ = NP + VB* + ?
        #      |    |     |
        #   first second third
        if first.token == 'NP' and self.__check_VB(second) and third.next_sibling == None:

            # SQ = NP + VB* + VP
            if third.token == 'VP':
                VB = second
                VP = third
                while (self.__check_VB(VP.first_child) and VP.first_child.next_sibling != None
                        and VP.first_child.next_sibling.token == 'VP'):
                    VB = VP.first_child
                    VP = VB.next_sibling
                # VP = VBN + [...]
                #      |
                #      fc
                _, fc = self.__check_ADVP(VP, VP.first_child)
                if ((VB.first_child.token != ''
                        and VB.first_child.token.split()[0] in ('is', 'are', 'was', 'were'))
                        and fc.token == 'VBN'):
                    if WH.token == 'WHADVP' and self.words[0] == 'how':
                        WH = self.__prefix_by_to_WH(WH)
                        self.__insert_after(WH, VP)
                        return SQ
                    if WH.token == 'WHADVP' and self.words[0] in ('why', 'where'):
                        self.__insert_after(WH, VP)
                        return SQ
                # VP = VB*
                #      |
                #      fc
                if self.__check_VB(fc) and fc.next_sibling == None:
                    self.__insert_after(WH, VP)
                    return SQ
                # VP = VB* + ?
                #      |     |
                #      fc    sc
                if (self.__check_VB(fc) and fc.next_sibling != None
                        and fc.next_sibling.next_sibling == None):
                    sc = fc.next_sibling
                    # VP = VB* + PRT
                    if sc.token == 'PRT':
                        self.__insert_after(WH, VP)
                        return SQ
                    # VP = VB* + PP
                    if sc.token == 'PP':
                        ffc = sc.first_child
                        if ffc.token == 'IN' and ffc.next_sibling == None:
                            self.__insert_after(WH, VP)
                            return SQ
                        if (ffc.token == 'IN' and ffc.next_sibling != None
                                and ffc.next_sibling.next_sibling == None):
                            ssc = ffc.next_sibling
                            if ssc.token in ('NP', 'ADJP'):
                                self.__insert_after(WH, fc)
                                return SQ
                    # VP = VB* + SBAR
                    if sc.token == 'SBAR':
                        if fc.first_child.token in ('know', 'think'):
                            if WH.token == 'WHADVP' and self.words[0] == 'how':
                                WH = self.__prefix_by_to_WH(WH)
                                self.__insert_after(WH, VP)
                                return SQ
                            self.__insert_after(WH, VP)
                            return SQ
                        self.__insert_after(WH, fc)
                        return SQ
                    # VP = VB* + S
                    if sc.token == 'S' and self.__tree_to_text(sc).startswith('(S(VP(TO to)(VP(VB'):
                        VB_S = sc.first_child.first_child.next_sibling.first_child
                        if VB_S.next_sibling == None:
                            self.__insert_after(WH, VP)
                            return SQ
                        if (VB_S.next_sibling.token == 'SBAR'
                                and VB_S.next_sibling.first_child.token == 'WHADVP'):
                            self.__insert_after(WH, VB_S)
                            return SQ
                        self.__insert_after(WH, fc)
                        return SQ
                    # VP = VB* + ADVP
                    if sc.token == 'ADVP':
                        self.__insert_after(WH, fc)
                        return SQ

                if WH.token == 'WHADVP' and self.words[0] == 'how':
                    WH = self.__prefix_by_to_WH(WH)
                    self.__insert_after(WH, VP)
                    return SQ
                self.__insert_after(WH, VP)
                return SQ

            # SQ = NP + VB* + NP
            if third.token == 'NP':
                self.__insert_after(WH, third)
                return SQ
            # SQ = NP + VB* + S
            if third.token == 'S' and self.__tree_to_text(third).startswith('(S(VP(TO to)(VP(VB'):
                VB_S = third.first_child.first_child.next_sibling.first_child
                if VB_S.next_sibling == None and WH.token == 'WHNP':
                    self.__insert_after(WH, VB_S)
                    return SQ
                self.__insert_after(WH, second)
                return SQ
            # SQ = NP + VB* + SBAR
            if third.token == 'SBAR' and third.first_child.token == 'WHADVP':
                self.__insert_after(WH, second)
                return SQ
            # SQ = NP + VB* + PP
            if third.token == 'PP':
                self.__insert_after(WH, third)
                return SQ
            # SQ = NP + VB* + ADJP
            if third.token == 'ADJP':
                if WH.token == 'WHADVP' and self.words[0] == 'how':
                    WH = self.__prefix_by_to_WH(WH)
                    self.__insert_after(WH, third)
                    return SQ
                self.__insert_after(WH, third)
                return SQ

        raise ValueError('Unknown SQ structure!')

    def __adjust_SBARQ_question(self, WH, SQ):
        """Adjust word order of SBARQ question.
        Pipeline:
          1. __convert_WH_to_answer();
          2. __adjust_SQ_in_SBARQ();
          3. __insert_WH_into_SQ().
        """
        #WH = self.root.first_child.first_child
        #SQ = WH.next_sibling

        WH = self.__convert_WH_to_answer(WH)
        SQ = self.__adjust_SQ_in_SBARQ(SQ, WH)
        SQ = self.__insert_WH_into_SQ(WH, SQ)

        self.root.first_child.first_child = SQ

# %%
tree = POSTree("(S1 (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (VBN expected) (NN ratio)) (PP (IN of) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ woolly) (NN fleece))))) (PP (TO to) (NP (NP (NN offspring)) (PP (IN with) (NP (DT a) (JJ hairy) (NN fleece)))))))) (. ?)))")
print(tree.adjust_order())
# Out:
# **blank** is the expected ratio of offspring with a woolly fleece to offspring with a hairy fleece

# %%
ambi = parser.parse("Which property do these three objects have in common?")
# clear = parser.parse("What is the temperature of the air on a cold, rainy day?")
# clear = parser.parse("What is the probability that a goat produced by this cross will be homozygous dominant for the myotonia congenita gene?")
# clear = parser.parse("What does pollen help a plant do?")
# clear = parser.parse("What is the expected ratio of offspring with a woolly fleece to offspring with a hairy fleece?")
# clear = parser.parse("Which of these occurs in the life cycles of all plants?")
clear = parser.parse("Which is most likely a direct cause of an ear infection?")
#print(best.get_reranker_best())
# print(ambi.get_parser_best())
# print(clear.get_parser_best())
s = str(clear.get_parser_best())
s = s[s.find('('):]
# print(s)
tree = POSTree(s)
print(tree.adjust_order())
# Out:
# **blank** is most likely a direct cause of an ear infection

# %%
def assertive_sentence_formation(question, answer):
  clear = parser.parse(question)
  s = str(clear.get_parser_best())
  s = s[s.find('('):]
  tree = POSTree(s)
  temp_question = tree.adjust_order()
  return temp_question.replace("**blank**",answer)

# %%
print(assertive_sentence_formation("Which is most likely a direct cause of an ear infection?", "mucus"))
# Out:
# mucus is most likely a direct cause of an ear infection

# %%
import json

f = open("/content/test.json")
ques_f = json.load(f)

len(ques_f)
# Out:
# 1000

# %%
ques_f[0]
# Out:
# {'question': 'Compounds that are capable of accepting electrons, such as o 2 or f2, are called what?',
#  'distractor3': 'residues',
#  'distractor1': 'antioxidants',
#  'distractor2': 'Oxygen',
#  'correct_answer': 'oxidants',
#  'support': 'Oxidants and Reductants Compounds that are capable of accepting electrons, such as O 2 or F2, are calledoxidants (or oxidizing agents) because they can oxidize other compounds. In the process of accepting electrons, an oxidant is reduced. Compounds that are capable of donating electrons, such as sodium metal or cyclohexane (C6H12), are calledreductants (or reducing agents) because they can cause the reduction of another compound. In the process of donating electrons, a reductant is oxidized. These relationships are summarized in Equation 3.30: Equation 3.30 Saylor URL: http://www. saylor. org/books.'}

# %%
assertive_sentences2=[]
for i in range(len(ques_f)):
  try:
    assertive_sentences2.append(assertive_sentence_formation(ques_f[i]["question"],ques_f[i]["correct_answer"]))
  except:
    continue

# %%
assertive_sentences2
# Out:
# ['clone in biotechnology means a genetically exact copy of an organism',
#  'the height above or below sea level is called elevation',
#  'plant hormones in plants control different processes',
#  'deciduous of tree is dominant in temperate forests',
#  'highly viscous of viscosity is found in long-chain hydrocarbons',
#  'mid-ocean ridges can be about 2 km',
#  'insects are by far the most common type of invertebrate',
#  'waves deposit sediments to form sandbars and barrier islands',
#  'a neon light produce visible light by electroluminescence',
#  'most living things use oxygen to make atp from glucose',
#  'feldspar and quartz are the two most common silicates',
#  'the amount of water means vapor in the air humidity',
#  'goosebumps happens when mammals raise their hair with tiny muscles in the skin',
#  'bone fractures are people with osteoporosis at increased risk of',
#  'between atoms is energy stored in a chemical substance',
#  "aluminum is the most abundant metal of the earth 's crust",
#  'thermal energy is the term for the total kinetic energy of moving particles of matter',
#  'pupil allows light to enter',
#  'the brain enters stem and influences activity in the cerebellum , spinal cord , and cerebral cortex vestibular system',
#  'a body cavity may be present or absent in triploblastic',
#  'central nervous system are the brain and spinal cord apart of',
#  'enzymes are biochemical catalysts that speed up biochemical reactions',
#  'genetic drift can cause harmful alleles to become fixed',
#  'fossil record shows that dinosaurs originated 200-250 million years ago',
#  'analytical balance is used to make very sensitive mass measurements in a laboratory , usually in grams',
#  "the purpose of bright colors is on a flower 's petals to attract pollinators",
#  'pi bonds are formed by the side-to-side overlap of p orbitals',
#  'backbone is another name for the vertebral column',
#  'the physical transformation of an insect is moving metamorphosis through stages of life',
#  'energy is required to move or change matter from one state to another',
#  'golden eagles is considered the largest of the raptors',
#  'nucleus contains positive protons and neutral neutrons',
#  'kidneys control the amount of water , ions , and other substances in the blood by excreting more or less of them in urine',
#  'one mole of measurement is defined to be the number of atoms in 12g of carbon-12',
#  'vision involves sensing and focusing light from people and objects',
#  'a marsupial is a therian mammal in which the embryo is born at an early , immature stage',
#  'parasitic are fungi which feed on living cells called',
#  'sedimentary offers the richest source of fossils',
#  'vision is the ability to see called',
#  'the spinal trigeminal nucleus is located medulla',
#  'prefixes are used to indicate the number of atoms of an element that are in the compound',
#  'camouflage is the adaptation that certain animals use to become less visible to predators and prey',
#  'coagulation is another term for blood clotting',
#  'you call the study of how organisms interact with their environment and each other ecology',
#  'implantation is the term for when an embryo fixes itself to the side of the uterus',
#  'cancer occurs when the cell cycle is no longer regulated',
#  'concentric circles on a topographic map indicate a hill',
#  'today arthropods segmentation have two unusual hox genes , both of which influence what',
#  'the little sacs at the end of the bronchioles are called alveoli',
#  'hair is a fiber that is found only in mammals',
#  'human welfare depend greatly on seed plants',
#  'ketones forms when secondary alcohols oxidize',
#  'cells without a nucleus are called prokaryotic cells',
#  'elephantiasis disease characterized by the extreme swelling of the limbs is caused by infection with a type of roundworm',
#  'the study of water movement , including waves and ocean currents is physical oceanography',
#  'the nucleus contains head',
#  'acid rain forms when nitrogen and sulfur oxides in air dissolve in rain',
#  'mushrooms get their energy decomposing dead organisms',
#  'gibberellins are the hormones that cause a plant to grow',
#  'cells are the smallest structural and functional unit of all living organisms',
#  'nitrogen oxides forms when nitrogen and oxygen combine at high temperatures',
#  'helicase opens two strands of dna',
#  'microcontinents come together to create continents and supercontinents',
#  'terrestrial biomes are classified by climatic factors and types of primary producers',
#  'carotid takes blood to the brain',
#  'hydrogen bonds holds together adenine and thymine',
#  'it makes so hard chemical bonds of diamond',
#  'mouse has a higher metabolic rate , a mouse or an elephant',
#  'the energy produced by plants come from sunlight',
#  'the earth is divided into crust, mantle, core three parts',
#  'genetic variation arises due to crossing over , independent assortment , and the random union of gametes',
#  'fish have short esophaguses because no lungs',
#  'birds broad animal group is thought to have evolved from theropod dinosaurs around 150 million years ago',
#  'hemoglobin is the protein in red blood cells which transports oxygen around the body',
#  'the circulatory system provides a major route for heat flow between the interior and exterior of the body',
#  'gravity is the term for the force that brings objects toward the earth',
#  'lamprey has a round sucker used to suck the blood of other fish',
#  'physical of change is undergone when the physical properties of a substance are changed',
#  'astronomers use light years to describe distances in space',
#  'osmosis is the process by which water moves through semi-permeable membranes from one part of the body to another',
#  'the phenotypic range of a particular genotype is called norm of reaction',
#  'neurons cells are the basis of nervous tissue',
#  'the testes is involved with the most common disorders',
#  'the term for air is moving wind over earth’s surface',
#  'dinosaurs are the best-known extinct vertebrates',
#  'marsupial is less risky for the mother',
#  'the term decay in chemistry refer to with regards to atoms changes in nuclei',
#  'it increases it increasing the temperature of reactants affect the rate of their reaction',
#  "lunar of eclipse happens when a full moon moves through earth 's shadow",
#  'genes structures located on chromosomes control characteristics of life and are passed from parents to offspring',
#  'plants of organisms helps hold soil in place to slow erosion',
#  'venus is named after the roman goddess of love',
#  'hydrocarbons are the simplest organic compounds',
#  'amphibians of animals are the first true tetrapods , vertebrates with four limbs',
#  'aging is telomere shortening associated with',
#  'carbon dioxide is released when dead organisms and other organic materials decompose',
#  'concave lens of lens is thicker at the edges than it is in the middle',
#  'increases happens to the pressure when more gas is added to a rigid container',
#  'three families are known quarks divided into',
#  'compact bone makes up the dense outer layer of bones',
#  'innate behaviors are rigid and predictable , and usually involve basic life functions',
#  'fossils is the term for the preserved remains or traces of organisms that lived in the past',
#  'nervous system of the body is responsible for transmitting , processing , and responding to most of the sensory information that is created by various stimuli',
#  'vascular or nonvascular plants lack nonvascular tracheids',
#  'the star nearest the earth is named proxima centauri',
#  'chemical state of solute are the majority of solution properties dependent upon',
#  'oxygen must be combined with a halogen to give it a positive oxidation number',
#  'magnetic force is the term for the force that a magnet exerts on certain materials',
#  'the skeletal system make blood cells',
#  'mitochondria organelles in a cell sequence enzyme and electron molecules for efficient cellular respiration',
#  'a solution forms when one substances dissolves in another',
#  'flowering plants are thought to have evolved at least 200 million years ago from gymnosperms like gnetae',
#  'friction is the force that opposes motion between two surfaces that are touching',
#  'water contain 3 atoms',
#  'visible light is the only light that people can see',
#  'linnaean system is the name of the system that consists of a hierarchy of taxa , from the kingdom to the species',
#  'solution is a mixture of a solute in a solvent called',
#  'ancient greeks particles propose atoms that matter consists of',
#  'biology is the official name for the study of life',
#  'an invertebrate , like a snail , not have backbone',
#  'seismic waves transmit the energy of an earthquake',
#  'prokaryotic cells divide binary fission',
#  'metabolic pathway is the term for a series of biochemical reactions by which an organism converts a given reactant to a specific end product',
#  'the nuclear envelope begin prophase i to break down',
#  'seeds are formed when cells from the male and female parts of the plant combine',
#  'microsporangia is another name for anther pollen sacs',
#  'vaginal secretions is released to lubricate the vagina to facilitate intercourse',
#  'we can learn speed about a wave by finding the product of the wavelength and frequency',
#  'liverworts are most often found along stream beds',
#  'a continuous string of earthquakes indicate eruption is close about a volcano',
#  'biodiversity is used to describe the variety of life and its processes , including the variety of living organisms , the genetic differences among them , and the communities and ecosystems in which they occur',
#  'inherited disorder of a disorder is tay-sachs disease',
#  'pituitary secretes growth hormones',
#  'impermeable of rock layer makes up the bottom of an aquifer',
#  'excursion is the side to side movement of the mandible called',
#  'epiphytes are plants that grow on other plants called',
#  'nervous system controls all five senses',
#  'nectar-feeding bats do to flowers pollinate',
#  'photoperiodism regulates the time of flowering in many species',
#  'trisomy 21 is the most common cause of down syndrome',
#  'cell division occurs not only as organisms grow , but as they reproduce',
#  'models useful tool helps scientists work with , understand and make predictions about extremely complex systems',
#  'fragmentation is the process of breaking an individual into parts followed by regeneration called',
#  'induction cooktops have electromagnets under their surface',
#  'two types of molecular orbitals can form from the overlap of two atomic s orbitals on adjacent atoms',
#  'tissue is the term for groups of cells with a similar appearance and a common function , and describes how cells are organized',
#  'psychrophiles need cold temperatures of weather to grow and reproduce',
#  'seafloor spreading creates new seafloor in the rift valleys',
#  'a reptiles skin is covered in to protect them from drying out scales',
#  'fossils provides clear evidence of evolution',
#  'meiosis begins with a diploid cell and ends with four haploid cells',
#  '100% of the field is tilled in traditional plowing',
#  'alveoli are at the end of the long air passages in the lungs',
#  'shingles is a disease caused by the same virus that causes chicken pox',
#  'it is called echo when sound is reflected off an object',
#  'autoimmune occur when the immune system attacks normal body cells',
#  'four haploid cells is produced by the end of meiosis',
#  'exothermic reactions release energy',
#  'pinocytosis is another word for cellular drinking',
#  'you call water that flows out of the ground where an aquifer meets the surface spring',
#  'you call the basic units of the structure and function of living things cells',
#  'sublimation is the conversion of a solid to a gas called',
#  'a patient’s blood has pass hemodialysis of dialysis through a length of tubing that travels through an artificial kidney machine',
#  'radioactive elements are the only type of elements capable of changing into different elements',
#  'the inside of all cells also contain cytosol',
#  'hair insulate , protect and provide sensory input',
#  'microwaves of waves are used in radar guns',
#  'the gallbladder is near on right lobe',
#  'cell division is used for cell growth , repair of cuts and replacement of worn out cells',
#  'astronomers term the stretching of space that causes the distance between galaxies to increase expanding universe',
#  'complete and incomplete are the two types of digestive systems invertebrates may have',
#  'the gradient of bicoid protein determine anterior-posterior axis',
#  'metastasized is used to describe a cancer that has spread',
#  'birds is the most abundant of all vertebrate classes , and the most recent to evolve',
#  'one gram of protein provide 4 calories of energy',
#  'remission is the cure of cancer known as',
#  'the outer layer of the exoskeleton is called cuticle',
#  'the life cycle of plants is so complex because alternation of generation',
#  'binary fission is a form of cell division in prokaryotic organisms that produces identical offspring',
#  'digestive system consists of organs that break down food and absorb nutrients such as glucose',
#  'the transition from solid to vapor is is called sublimation',
#  'the sun is the most important source of electromagnetic radiation on earth',
#  'antiviral drugs of drugs are formulated to help deal with hiv and herpes as well as influenza and two types of hepatitis',
#  'abundant resources is essential for population of all species to expand greatly',
#  'petals is usually the most visible part of the flower',
#  'ionic bonds form between metals and nonmetals',
#  'specialization occurs when competing species evolve different adaptations',
#  'radio telescopes collect and focus radio waves from distant objects',
#  'alleles are different versions of a gene known as',
#  'reproduction is the process by which organisms give rise to offspring',
#  'combustion engine is a complex machine that burns fuel to produce thermal energy and then uses the thermal energy to do work',
#  'it is called melting when ice changes to liquid water',
#  'sporopollenin protects the pollen of seed plants and spores of seedless plants',
#  'glycolsis is first stage of cellular respiration',
#  'groups of stars are called star clusters that are smaller than a galaxy',
#  'they are lower happens to air density and pressure when gas molecules are warm',
#  'sexual reproduction of reproduction generates most of the genetic variation that makes evolutionary adaptation possible',
#  'nematodes can both be a parasite of plants , animals , or both',
#  'you can expect stormy of weather if a center of low pressure is moving your way',
#  'eardrum is a thin membrane stretched tight across the end of the ear canal that vibrates when sound waves strike it',
#  'era geologic is also known as the age of mammals cenozoic era',
#  'solute and solvent are the two components of all solutions',
#  'tundra is land with permafrost , no trees , and small hardy plants',
#  'melatonin secreted by the pineal gland controls sleep-wake cycles and several other processes',
#  'energy is defined as the ability to do work',
#  'adipose and collagenous two types of tissue compose most of the non-pregnant and non-lactating female breast',
#  'the pistil is the female reproductive structure of a flower',
#  'aristotle developed a classification system that divided living things into several groups that we still use today , including mammals , insects , and reptiles',
#  'organ is a structure that is composed of one or more types of tissues',
#  'different types of tissues organized into functional units are called organs',
#  'atoms of the same element that differ in their numbers of neutrons are called isotopes',
#  'solvent is added to a measured portion of a more concentrated stock solution to achieve a particular concentration',
#  'humans and bats have physically in common body hair',
#  'impulse is a vector quantity with the same direction as the force called',
#  'seeds have a supply of stored food that spores do not',
#  'nitrogen cycle is the process called where nitrogen is repeatedly recycled through the biosphere',
#  'pepsin help break down into amino acids proteins',
#  'angiosperms are the most successful phylum of plants',
#  'the term for the ability of an atom to emit , or give off , charged particles and energy is from its nucleus radioactivity',
#  'amniotic of fluid cushions the fetus and helps protect it from injury',
#  'you can prevent diseases such as whooping cough and flu by preventive vaccinations',
#  'snakes have venomous bites because to kill prey',
#  'cancers results from uncontrolled cell division',
#  'angiosperms form seeds ovaries',
#  'technological design is used to describe the development of new technology',
#  'bohr model model describing atomic structure is often referred to as a planetary model',
#  'plants take their leaves in air',
#  'a viral vector is the name for a tool commonly used by molecular biologists to place genetic material into cells',
#  'dynamics is the study of how forces affect the motion of objects',
#  'metamorphic form when an existing rock is changed by heat or pressure',
#  'jupiter reflect a lot of due to its size sunlight',
#  'a process developed to remove carbon and dust particles in smoke frederick cottrell',
#  'gases are called greenhouse gases that absorb heat in the atmosphere',
#  'collar cells are the specialized cells that sponges have',
#  'circular are the muscles that control the anus',
#  'autoinducers are the small molecules or proteins produced by bacteria that regulate gene expression',
#  'a rock that contains important minerals is called ore',
#  'air is made of molecules of many different gases , and is something we usually can’t see , taste , or smell ; we can only feel it when it moves',
#  'living things that produce food for themselves and other organisms are called producers',
#  'nonmetals is the second largest class of elements',
#  'solids are with high melting and boiling points ionic compounds',
#  'bacterial and eukaryotic of cells are polyribosomes found in',
#  'thyroid is controlled by a negative feedback loop that includes the hypothalamus and pituitary gland',
#  'metallurgy means the set of processes by which metals are extracted from their ores and converted to more useful forms',
#  'veins contain one-way valves that contribute to the return of blood to the heart',
#  'chemical elements and water pass through during ecosystem recycle biotic and abiotic',
#  "length is the measurement of something along it 's greatest dimension called",
#  'carbon chains form the skeletons of most organic molecules',
#  'the process of vesicles describes fusing with the plasma membrane and releasing their contents to the outside of the cell exocytosis',
#  'electrolysis is the most direct way of recovering a metal from its ores',
#  'micronutrients is the term used to describe the minerals and vitamins that are not needed for providing the body with energy but are still essential for good health',
#  'topographic of map reveals the shape of a landscape',
#  'atmospheric pressure decreases increase or decrease as the altitude increases',
#  'deceleration always refers to acceleration in the direction opposite to the direction of the velocity and always reduces speed , unlike negative acceleration',
#  'you call a quantity of motion that has both size as well as direction vector',
#  'particles of the same charge do to each other repel',
#  'fossilization is the the process by which remains or traces of living things become fossils called',
#  'commensalism is a relationship where one species benefits and the other is unaffected',
#  'radioactivity is used to describe is the spontaneous emission of particles and radiation from atomic nuclei',
#  'metals start out as ore',
#  'newton (n) is the si unit for weight',
#  'net primary productivity is an estimation of all of the organic matter available as food , and involves measuring biomass in terrestrial environments',
#  'lava slowly flow quickly or slowly when thick',
#  'felsic magmas is the term for viscous magmas that are high in silica and tend to stay below the surface or erupt explosively',
#  'the photic zone extend 200 meters deep',
#  'nuclear fission is the name of the process in which the nuclei of uranium atoms are split',
#  'covalent are formed between atoms sharing electrons',
#  'a neutron of particle collides with an atom of u-235 during the basic nuclear fission process',
#  'blue is phosphate mineral turquoise',
#  'two ways are there for a species to go extinct',
#  'krebs is part of cellular respiration and makes atp and naph',
#  'abrasion of mechanical weathering occurs when one rock bumps against another rock',
#  'sex hormones of hormones serve many functions in addition to promoting gamete production',
#  'high tides occur every 12 hours',
#  'the cell make final preparations to divide growth phase 2',
#  'multicellular organisms grow increase size and number of cells in size',
#  'arrow is used to indicate directionality in chemical reactions',
#  'darwin wrote the book on the origin of species',
#  'milk is considered a good source of calcium',
#  'peripheral nervous system is divided into two parts , the sensory division and the motor division',
#  'beneficial fungi play balance of ecosystems crucial role',
#  'bacteria are the most diverse organisms on earth , which are often classified by shape or how they react to gram stain',
#  'there are 6 viruses that can cause cancer in humans have been identified by scientists',
#  'pedigree is utilized to analyze simple mendelian inheritance',
#  'chordates is the only animal phyla that does not consist exclusively of invertebrates',
#  'medications can slow down the increase of viruses in the blood',
#  'plasmodesmata is the name of microscopic channels which traverse the cell walls of plants',
#  'an adaptation is favorable trait',
#  'potential energy is the energy that matter possesses because of its location or structure',
#  'homeostasis is the term for the relatively stable state inside the body of an animal',
#  'the middle layer of connective tissue is called perimysium',
#  'airborne mold spores is the cause of common mold allergies',
#  'gastro-esophageal sphincter is located at the stomach end of the esophagus and opens to allow the bolus to enter the stomach',
#  'prey helps hide camouflage and predators sneak up on prey',
#  'specific ions is one thing that cell membranes are permeable to',
#  'galvanic of a process is corrosion',
#  'linear acceleration is equal to the angular acceleration multiplied by the radius of the rotating object',
#  'the membrane is lining the back of the eye called retina',
#  'amphibians of animals has adapted to live in both water and on land',
#  'pressure receptors are mainly found the skin',
#  'the cranium is the name of the skull that covers the brain and protects it',
#  'it bends happens to light when it passed from air to water',
#  'liquid and solid states is the difference between oils and fats at room temperature',
#  'the helix nebula is located in aquarius',
#  'mitosis is the term for the multi-phase process in which the nucleus of the cell divides',
#  'streak is a more reliable trait or measure to identify minerals',
#  'methane is the name of the molecule which has one carbon and four hydrogen atoms',
#  "coral reefs comprise the `` rainforests of the oceans ''",
#  'endothermic absorb heat from their surroundings',
#  'ethology is an extension of genetics , evolution , anatomy , physiology , and other biological disciplines',
#  'catalysts in living things are called enzymes',
#  'mushroom is part of a large fungus that lives underground',
#  'cells causes to divide if cytokinins are added to it auxin',
#  'removed happens to energy when work is done by a system',
#  'carbohydrates is used to describe organic compounds such as sugars and starches',
#  'scales indicates horizontal distance and are also found on the map legend',
#  'the blood is in the body pumped with heart',
#  'small hydrophobic molecules squeeze simple of diffusion through lipid molecules',
#  'the water cycle end it repeats itself',
#  'dna and proteins are chromosomes made of',
#  'alkyl group is the general name for a group of atoms derived from an alkane',
#  'water are most cells surrounded by',
#  'solids is the term for materials that have both a defined shape and a defined volume',
#  'fission is the radioactive process used in nuclear power plants and one type of nuclear bomb',
#  'a crossover occur at different locations on a chromosome',
#  'the biggest groups of stars are called galaxies',
#  'pollution is defined as the act of contaminating the environment with waste',
#  'mechanical of energy is produced when two objects move together',
#  'natural selection is the mechanism by which favorable traits become more common in organisms over the course of generations',
#  'nephrons are the structural and functional units of the kidneys',
#  'the ovule mature into after double fertilization a seed',
#  "most of the earth 's energy come from sun",
#  'we call a carbohydrate formed by two monosaccharides bonding together disaccharide',
#  "distance determines how long a planet 's orbit is around the sun",
#  'atherosclerosis is the term for buildup of cell debris and cholesterol inside the arteries',
#  'b cells are produced in the body lymphocytes',
#  'convex of mirror is shaped like the outside of a bowl',
#  'gases and liquids become solids at low temperatures',
#  'mitochondria divide on their own by a process that resembles binary fission in prokaryotes',
#  'cilia are tiny hairs that line the bronchi called',
#  'menstrual cycle occurs in women of reproductive age , as a long as a sperm does not enter an egg',
#  'the alpine tundra causes to be so cold high altitude above sea level',
#  'you call materials able to conduct electricity with 100 % efficiency , meaning that no energy is lost during the electrical transmission superconductors',
#  'scientific notation use exponents to write very large or very small numbers',
#  'tiny air sacs in the lungs are alveoli',
#  'milk is the name of the complex mixture that consists of water , proteins , fats , carbohydrates , and minerals',
#  'cancer is the result of unchecked cell division caused by a breakdown of the mechanisms regulating the cell cycle',
#  'clone is the term for an exact genetic copy',
#  'recent rocks point towards on earth north magnetic pole',
#  'muscle of cell function relies on microfilaments , which are the actin components of the cytoskeleton',
#  'dissociation is the separation of ions that occurs when a solid ionic compound dissolves',
#  'charged particles in motion generate magnetic fields',
#  'hydrogen bonding is formed in polar amino acid side chains',
#  'seismic waves is the name for the energy waves that radiate out from the center of an earthquake',
#  'ecologists study ecosystems at every level',
#  'kingdom is the broadest category in the linnaean system',
#  'axis is the term for what the earth rotates on',
#  'pyruvate is the end product of glycolysis',
#  'glycogen is stored mainly in liver and muscle cells by humans and other vertebrates',
#  'pedalfer is common in deciduous forests',
#  'voltmeters measure the voltage drop across a resistor',
#  'scientists think protists to be the oldest eukaryotes',
#  'the first seed plants form seeds by in cones',
#  'chloroplasts of a leaf are visible under a high power microscope',
#  'the reaction rate indicates the speed at which a reaction proceeds',
#  'the coast of california have mediterranean',
#  'experts estimate is the cause for the extinction of hundreds of species every year human activities',
#  'chemistry of science is concerned with matter and the changes that it can undergo',
#  'the plasma membrane help keep its shape cholesterol',
#  'liquid of matter has a fixed volume but not a fixed shape',
#  'is closed reduction simpler than open reduction in bone repair because no surgery needed',
#  'methanogens act as in sewage treatment plants as decomposers',
#  'meninges protects the brain and spinal cord in the central nervous system',
#  'clots occur in arteries that can cause heart attacks and strokes',
#  'it is called transform plate boundary when two plates slide past each other in opposite directions',
#  'friction occurs because no surface is perfectly smooth',
#  'lymph capillaries collect fluid that leaks out from blood capillaries',
#  'the eighth planet is from our sun neptune',
#  'cytoplasm is dna located in prokaryotic cells',
#  'flowers are plant structures that contain male and/or female reproductive organs',
#  'lymph is the watery fluid that bathes tissues and organs and contains protective white blood cells but does not contain erythrocytes',
#  'adult tunicates have that siphon water in and out of the body two openings',
#  'the term for the combined forces is acting net force on an object',
#  'light reactions is the name of the first stage of photosynthesis',
#  'endothermic tetrapod are vertebrates most commonly called birds',
#  'the synapse is the space between a neuron and the next cell',
#  'you call nutrients that your body needs in fairly large amounts macronutrients',
#  'help digest food is the most important function of enzymes in animals',
#  'one mutated allele is needed for a person to be affected by an autosomal dominant disorder',
#  'we call a simple machine that consists of a rope and grooved wheel pulley',
#  'you call health-promoting molecules that inhibit the oxidation of other molecules antioxidants',
#  'the passing of traits from parents to offspring is called heredity',
#  'the sun is the most important source of electromagnetic waves on earth',
#  'greenhouse gasses trap heat in troposphere of the atmosphere',
#  'complex placenta are the fetuses of eutherian mammals connected to their mothers during gestation',
#  'the flattened , disk-shaped cells are in blood that carry oxygen red blood cells',
#  'dark matter is matter in the universe that does not emit light called',
#  'heat is most energy that is lost to the environment lost as',
#  'oxygen is the resultant waste product of photosynthesis',
#  'velocity is the term for a measure of both speed and direction',
#  'a stream is a body of freshwater that flows downhill in a channel',
#  'asexual of reproduction creates offspring that are genetically identical to the parent',
#  'open and globular are the two main types of star clusters',
#  'most waves at an angle strike the shore head on or at an angle',
#  'yeast has been used in brewing , winemaking and baking for thousands of years',
#  'oxygen are reptiles unable to absorb through their skin because of scales',
#  'pleiotropic effects causes symptoms associated with sickle-cell disease',
#  'sensory nerve cells detect stimuli',
#  'animals need air, water, and food 3 things to live and survive',
#  'ionic compounds compounds form crystals instead of molecules',
#  'photosynthesis is the process by which plants make the simple sugar glucose from carbon dioxide and water is called',
#  'turning driveshaft causes the wheels of the car to turn',
#  'polar and nonpolar are the two terms that designate how well aqueous solutions conduct electricity',
#  "one river system separates 's basin from another river system 's basin a divide",
#  'adaptive immune system possesses a memory component that allows for an efficient and dramatic response upon reinvasion of the same pathogen',
#  'sweat glands glands remove water , salts and other wastes from skin',
#  'metalloids is the third class of elements after metals and nonmetals',
#  'carbon is present in all organic molecules',
#  'volcanoes are located along convergent and divergent plate boundaries',
#  'cell body is a large structure with a central nucleus',
#  'xerophytes are plants that are adapted to very dry environments called',
#  'sensory neurons carry nerve impulses from sense organs and internal organs to the central nervous system',
#  'an adult skeleton have 206 bones',
#  'the transfer of heat is by physical contact conduction',
#  'fatty acids acids are the structural components of many lipids and may be saturated or unsaturated',
#  'addictive drugs affect reward system',
#  'conduct electricity happens when ionic compounds are dissolved in water',
#  'differentiation is the process in which unspecialized cells become specialized in structure and function to perform certain tasks in the body',
#  'five types of basic sensory receptors are there',
#  'covalent is the force of attraction that holds together two atoms that share a pair of valence electrons',
#  'nonvascular plants were the first plants to evolve',
#  'wavelength describes the distance between two corresponding points on adjacent waves',
#  'decomposers break down dead organisms and other organic waste and release inorganic molecules back to the environment called',
#  'the science of classifying living things is called taxonomy',
#  'drought makes marginal lands unsuitable for farming',
#  'it expands happens to water when it freezes',
#  'buoyancy is the term for the ability of a fluid to exert an upward force on any object placed in it',
#  'kinetic theory states that there is no interaction between individual gas particles',
#  'sharks is one of the most frequently studied cartilaginous fish',
#  'mammals have a layer of fat under the skin to help insulate the body',
#  'hydrogen is the most abundant in the universe',
#  'tetrahedral is the electron domain geometry of ammonia',
#  'cell is the basic unit of the structure and function of living things',
#  'ecosystems absorb energy on the earth',
#  'populations can grow under ideal exponentially',
#  "there are five mass extinctions have occurred throughout earth 's history",
#  'energy refers to the ability to change or move matter and is required by all life processes and living things',
#  'we call the visible part of the electromagnetic spectrum light',
#  'oceanic of crust is made of basalt lavas that flow onto the seafloor',
#  'changes to rocks slowly happen quickly or slowly',
#  'polymer is a large molecule with many repeating units',
#  'clouds and dust absorbs , scatters , or reflects most incoming solar radiation in the atmosphere',
#  'many mammals control their body temperature by sweating',
#  'nucleic acids is defined by its sequence of nucleotides',
#  'pseudocoelom in roundworms is a partial body cavity filled with fluid',
#  'digestive system breaks down food and absorbs nutrients',
#  'diabetes is unpreventable in the type one form but may be prevented by diet if it is of the second type',
#  'you call a chemical process used to treat water by destroying a contaminant chemical remediation',
#  'ocean acidification occurs when excess carbon dioxide in the atmosphere causes the oceans to become acidic',
#  'cardiac muscle of muscle is the heart mainly composed of',
#  'physical science of science explains much of what you observe and do in your daily life',
#  'progesterone prevents new ovarian follicles from developing and suppresses uterine contractility',
#  'nuclear of bombs put a much larger fraction of their output into thermal energy than do conventional bombs',
#  'it cools happens to water vapor as it rises',
#  'it is called incubation when birds keep their eggs warm while the embryos inside develop',
#  'slump leaves behind crescent-shaped scars on a hillside and may be caused by a layer of slippery , wet clay underneath the rock and soil on a hillside',
#  'lungs is the organ system that brings oxygen into the body and releases carbon dioxide',
#  'the union of the cytoplasms of two parent mycelia known as is plasmogamy',
#  "there are in a bird 's heart 4 chambers",
#  'molecular formula shows only the kinds and numbers of atoms in a molecule',
#  'atoms are the smallest particles of matter',
#  'animals obtain nitrogen by eating plants or organisms',
#  't cells mature thymus gland',
#  'oviparous describes reproducing by external fertilization after the female sheds large numbers of small eggs',
#  'cell membrane allows some things to enter the cell while keeping other things out',
#  'the term for something is changing from water to ice freezing',
#  'an individual with more than the correct number of chromosome is sets called polyploid',
#  'forming of reproductive cells takes place where septa is found',
#  'extrusive igneous rocks cool at surface',
#  'citric acid is citrate an ionized form of',
#  'phosphatase functions in removing phosphorylated amino acids from proteins',
#  'freshwater biomes have water containing little or no salt',
#  'a solution with a ph lower than 7 is called acid',
#  'sensory of the peripheral nervous system interprets signals , while the motor division sends signals',
#  'fossil record provides evidence that new species develop to fill the habitats where old species lived following a mass extinction',
#  'dialysis is the process of filtering waste from the kidneys',
#  'kinetic theory of matter states that all matter consists of constantly moving particles',
#  'blood pressure is written as systolic over diastolic',
#  'to attract mates is the purpose of a bird using flashy displays',
#  'you call the ancient cores of continents , where the earliest continental crust is now found cratons',
#  'short period comets come from kuiper belt',
#  'atoms with unstable nuclei are are considered to be radioactive',
#  'atmospheric sulfur is found in sulfur dioxide (so2)']

# %%
len(assertive_sentences2)
# Out:
# 6019

# %%
import pickle

with open('assertive_sentences_unfiltered2.pkl', 'wb') as f:
   pickle.dump(assertive_sentences2, f)
